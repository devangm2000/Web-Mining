# %%
import re
from bs4 import BeautifulSoup
from urllib import request

# %%
#1

# %%
url = "https://en.wikipedia.org/wiki/Web_mining"
html = request.urlopen(url).read().decode('utf8')
raw = BeautifulSoup(html, 'html.parser').get_text()

# %%
print(raw)
# Out:
# Web mining - Wikipedia
# document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"8ac52718-95ac-4904-a785-666125065813","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Web_mining","wgTitle":"Web mining","wgCurRevisionId":965466027,"wgRevisionId":965466027,"wgArticleId":797887,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 errors: missing periodical","Articles needing cleanup from June 2009","All pages needing cleanup","Cleanup tagged articles without a reason field from June 2009","Wikipedia pages needing cleanup from June 2009","Articles to be expanded from June 2015","All articles to be expanded",
# "Articles using small message boxes","Articles lacking in-text citations from September 2009","All articles lacking in-text citations","Web analytics","Data mining","World Wide Web"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Web_mining","wgRelevantArticleId":797887,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q785337"};
# RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","mediawiki.toc.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns"
# ,"ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];
# (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Web mining
#
# From Wikipedia, the free encyclopedia
#
#
#
# Jump to navigation
# Jump to search
# This article may require cleanup to meet Wikipedia's quality standards. No cleanup reason has been specified. Please help improve this article if you can. (June 2009) (Learn how and when to remove this template message)
# Web mining is the application of data mining techniques to discover patterns from the World Wide Web. As the name proposes, this is information gathered by mining the web. It makes utilization of automated apparatuses to reveal and extricate data from servers and web2 reports, and it permits organizations to get to both organized and unstructured information from browser activities, server logs, website and link structure, page content and different sources.
# The goal of Web structure mining is to generate structural summary about the Web site and Web page. Technically, Web content mining mainly focuses on the structure of inner-document, while Web structure mining tries to discover the link structure of the hyperlinks at the inter-document level. Based on the topology of the hyperlinks, Web structure mining will categorize the Web pages and generate the information, such as the similarity and relationship between different Web sites.
# Web structure mining can also have another direction – discovering the structure of Web document itself. This type of structure mining can be used to reveal the structure (schema) of Web pages, this would be good for navigation purpose and make it possible to compare/integrate Web page schemes. This type of structure mining will facilitate introducing database techniques for accessing information in Web pages by providing a reference schema.
#
# Contents
#
# 1 Web mining types
# 2 Web usage mining
#
# 2.1 Pros
# 2.2 Cons
#
#
# 3 Web structure mining
# 4 Web content mining
#
# 4.1 Web content mining in foreign languages
#
# 4.1.1 Chinese
#
#
#
#
# 5 See also
# 6 References
# 7 Resources
#
# 7.1 External links
# 7.2 Books
# 7.3 Bibliographic references
#
#
#
#
# Web mining types[edit]
# Web mining can be divided into three different types – Web usage mining, Web content mining and Web structure mining.
#
#  The general relationship between the categories of Web mining and objectives of data mining
#
# Comparison of Web mining types[1]
#
#
#
#
# Web content mining
#
# Web structure mining
#
# Web usage mining
#
#
#
#
# IR view
#
# DB view
#
#
# View of data
#
#
# Unstructured
# Structured
#
#
# Semi-structured
# Web site as DB
#
#
# Link structure
#
#
# Interactivity
#
#
# Main data
#
#
# Text documents
# Hypertext documents
#
#
# Hypertext documents
#
#
# Link structure
#
#
# Server logs
# Browser logs
#
#
# Representation
#
#
# Bag of words, n-gram terms
# phrases, concepts or ontology
# Relational
#
#
# Edge labed graph
# Relational
#
#
# Graph
#
#
# Relational table
# Graph
#
#
# Method
#
#
# Machine learning
# Statistical (including NLP)
#
#
# Proprietary algorithms
# Association rules
#
#
# Proprietary algorithms
#
#
# Machine learning
# Statistical
# Association rules
#
#
# Application categories
#
#
# Categorization
# Clustering
# Finding extract rules
# Finding patterns in text
#
#
# Finding frequent sub structures
# Web site schema discovery
#
#
# Categorization
# Clustering
#
#
# Site construction
# Adaptation and management
#
# Web usage mining[edit]
# Web usage mining is the application of data mining techniques to discover interesting usage patterns from Web data in order to understand and better serve the needs of Web-based applications.
# Usage data captures the identity or origin of Web users along with their browsing behavior at a Web site.
# Web usage mining itself can be classified further depending on the kind of usage data considered:
#
# Web server data: The user logs are collected by the Web server. Typical data includes IP address, page reference and access time.
# Application server data: Commercial application servers have significant features to enable e-commerce applications to be built on top of them with little effort. A key feature is the ability to track various kinds of business events and log them in application server logs.
# Application level data: New kinds of events can be defined in an application, and logging can be turned on for them thus generating histories of these specially defined events. Many end applications require a combination of one or more of the techniques applied in the categories above.
# Studies related to work[2] are concerned with two areas: constraint-based data mining algorithms applied in Web usage mining and developed software tools (systems). Costa and Seco demonstrated that web log mining can be used to extract semantic information (hyponymy relationships in particular) about the user and a given community.
#
# Pros[edit]
# Web usage mining essentially has many advantages which makes this technology attractive to corporations including government agencies. This technology has enabled e-commerce to do personalized marketing, which eventually results in higher trade volumes. Government agencies are using this technology to classify threats and fight against terrorism. The predicting capability of mining applications can benefit society by identifying criminal activities. Companies can establish better customer relationship by understanding the needs of the customer better and reacting to customer needs faster. Companies can find, attract and retain customers; they can save on production costs by utilizing the acquired insight of customer requirements. They can increase profitability by target pricing based on the profiles created. They can even find customers who might default to a competitor the company will try to retain the customer by providing promotional offers to the specific customer, thus reducing the risk of losing a customer or customers.
# More benefits of web usage mining, particularly in the area of personalization, are outlined in specific frameworks such as the probabilistic latent semantic analysis model, which offer additional features to the user behavior and access pattern.[3] This is because the process provides the user with more relevant content through collaborative recommendation. These models also demonstrate a capability in web usage mining technology to address problems associated with traditional techniques such as biases and questions regarding validity since the data and patterns obtained are not subjective and do not degrade over time.[4] There are also elements unique to web usage mining that can show the technology's benefits and these include the way semantic knowledge is applied when interpreting, analyzing, and reasoning about usage patterns during the mining phase.[5]
#
# Cons[edit]
# Web usage mining by itself does not create issues, but this technology when used on data of personal nature might cause concerns. The most criticized ethical issue involving web usage mining is the invasion of privacy. Privacy is considered lost when information concerning an individual is obtained, used, or disseminated, especially if this occurs without the individual's knowledge or consent.[6] The obtained data will be analyzed, made anonymous, then clustered to form anonymous profiles.[6] These applications de-individualize users by judging them by their mouse clicks rather than by identifying information. De-individualization in general can be defined as a tendency of judging and treating people on the basis of group characteristics instead of on their own individual characteristics and merits.[6]
# Another important concern is that the companies collecting the data for a specific purpose might use the data for totally different purposes, and this essentially violates the user's interests.
# The growing trend of selling personal data as a commodity encourages website owners to trade personal data obtained from their site. This trend has increased the amount of data being captured and traded increasing the likeliness of one's privacy being invaded. The companies which buy the data are obliged make it anonymous and these companies are considered authors of any specific release of mining patterns. They are legally responsible for the contents of the release; any inaccuracies in the release will result in serious lawsuits, but there is no law preventing them from trading the data.
# Some mining algorithms might use controversial attributes like sex, race, religion, or sexual orientation to categorize individuals. These practices might be against the anti-discrimination legislation.[7] The applications make it hard to identify the use of such controversial attributes, and there is no strong rule against the usage of such algorithms with such attributes. This process could result in denial of service or a privilege to an individual based on his race, religion or sexual orientation. This situation can be avoided by the high ethical standards maintained by the data mining company. The collected data is being made anonymous so that, the obtained data and the obtained patterns cannot be traced back to an individual. It might look as if this poses no threat to one's privacy, however additional information can be inferred by the application by combining two separate unscrupulous data from the user.
#
# Web structure mining[edit]
# This section needs expansion. You can help by adding to it. (June 2015)
# Web structure mining uses graph theory to analyze the node and connection structure of a web site. According to the type of web structural data, web structure mining can be divided into two kinds:
#
# Extracting patterns from hyperlinks in the web: a hyperlink is a structural component that connects the web page to a different location.
# Mining the document structure: analysis of the tree-like structure of page structures to describe HTML or XML tag usage.
# Web structure mining terminology:
#
# Web graph: directed graph representing web.
# Node: web page in graph.
# Edge: hyperlinks.
# In degree: number of links pointing to particular node.
# Out degree: number of links generated  from particular node.
# Techniques of web structure mining:
#
# PageRank: this algorithm is used by Google to rank search results. The name of this algorithm is given by Google-founder Larry Page. The rank of a page is decided by the number of links pointing to the target node.
# Web content mining[edit]
# Web content mining is the mining, extraction and integration of useful data, information and knowledge from Web page content. The heterogeneity and the lack of structure that permits much of the ever-expanding information sources on the World Wide Web, such as hypertext documents, makes automated discovery, organization, and search and indexing tools of the Internet and the World Wide Web such as Lycos, Alta Vista, WebCrawler, Aliweb, MetaCrawler, and others provide some comfort to users, but they do not generally provide structural information nor categorize, filter, or interpret documents. These factors have prompted researchers to develop more intelligent tools for information retrieval, such as intelligent web agents, as well as to extend database and data mining techniques to provide a higher level of organization for semi-structured data available on the web. The agent-based approach to web mining involves the development of sophisticated AI systems that can act autonomously or semi-autonomously on behalf of a particular user, to discover and organize web-based information.
# Web content mining is differentiated from two different points of view:[8] Information Retrieval View and Database View.[9] summarized the research works done for unstructured data and semi-structured data from information retrieval view. It shows that most of the researches use bag of words, which is based on the statistics about single words in isolation, to represent unstructured text and take single word found in the training corpus as features. For the semi-structured data, all the works utilize the HTML structures inside the documents and some utilized the hyperlink structure between the documents for document representation. As for the database view, in order to have the better information management and querying on the web, the mining always tries to infer the structure of the web site to transform a web site to become a database.
# There are several ways to represent documents; vector space model is typically used. The documents constitute the whole vector space.  This representation does not realize the importance of words in a document. To resolve this, tf-idf (Term Frequency Times Inverse Document Frequency) is introduced.
# By multi-scanning the document, we can implement feature selection. Under the condition that the category result is rarely affected, the extraction of feature subset is needed. The general algorithm is to construct an evaluating function to evaluate the features. As feature set, information gain, cross entropy, mutual information, and odds ratio are usually used.
# The classifier and pattern analysis methods of text data mining are very similar to traditional data mining techniques. The usual evaluative merits are classification accuracy, precision and recall and information score.
# Web mining is an important component of content pipeline for web portals. It is used in data confirmation and validity verification, data integrity and building taxonomies, content management, content generation and opinion mining.[10]
# Web mining can complement the retrieval of structured data transmitted with open protocols like OAI-PMH: an example is the aggregation of works from academic publications,[11] which are mined to identify open access versions through a mix of open source and open data methods by academic databases like Unpaywall.[12]
#
# Web content mining in foreign languages[edit]
# Chinese[edit]
# The language code of Chinese words is very complicated compared to that of English. The GB, Big5 and HZ code are common Chinese word codes in web documents. Before text mining, one needs to identify the code standard of the HTML documents and transform it into inner code, then use other data mining techniques to find useful knowledge and useful patterns.
#
# See also[edit]
# Web intelligence
# Web analytics
# Web scraping
# Wikipedia:Data mining Wikipedia
# References[edit]
#
#
# ^ Galitsky B., Dobrocsi G., de la Rosa J. L., Kuznetsov S. O..  Using generalization of syntactic parse trees for taxonomy capture on the web. ICCS. 2011;8323.
#
# ^ Weichbroth et al.
#
# ^ Ngu, Anne; Kitsuregawa, Masaru; Chung, Jen-Yao; Neuhold, Erich; Sheng, Quan (2005). Web Information Systems Engineering – WISE 2005. Berlin: Springer. pp. 15. ISBN 9783540300175..mw-parser-output cite.citation{font-style:inherit}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .id-lock-free a,.mw-parser-output .citation .cs1-lock-free a{background-image:url("//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Lock-green.svg/9px-Lock-green.svg.png");background-image:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/6/65/Lock-green.svg");background-repeat:no-repeat;background-size:9px;background-position:right .1em center}.mw-parser-output .id-lock-limited a,.mw-parser-output .id-lock-registration a,.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background-image:url("//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Lock-gray-alt-2.svg/9px-Lock-gray-alt-2.svg.png");background-image:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/d/d6/Lock-gray-alt-2.svg");background-repeat:no-repeat;background-size:9px;background-position:right .1em center}.mw-parser-output .id-lock-subscription a,.mw-parser-output .citation .cs1-lock-subscription a{background-image:url("//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Lock-red-alt-2.svg/9px-Lock-red-alt-2.svg.png");background-image:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/a/aa/Lock-red-alt-2.svg");background-repeat:no-repeat;background-size:9px;background-position:right .1em center}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration{color:#555}.mw-parser-output .cs1-subscription span,.mw-parser-output .cs1-registration span{border-bottom:1px dotted;cursor:help}.mw-parser-output .cs1-ws-icon a{background-image:url("//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/12px-Wikisource-logo.svg.png");background-image:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg");background-repeat:no-repeat;background-size:12px;background-position:right .1em center}.mw-parser-output code.cs1-code{color:inherit;background:inherit;border:inherit;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;font-size:100%}.mw-parser-output .cs1-visible-error{font-size:100%}.mw-parser-output .cs1-maint{display:none;color:#33aa33;margin-left:0.3em}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration,.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left,.mw-parser-output .cs1-kern-wl-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right,.mw-parser-output .cs1-kern-wl-right{padding-right:0.2em}.mw-parser-output .citation .mw-selflink{font-weight:inherit}
#
# ^ Bauknecht, Kurt; Madria, Sanjay; Pernul, Gunther (2000). Electronic Commerce and Web Technologies: First International Conference, EC-Web 2000 London, UK, September 4-6, 2000 Proceedings. Berlin: Springer. pp. 165. ISBN 978-3540679813.
#
# ^ Scime, Anthony (2005). Web Mining: Applications and Techniques. Hershey, PA: Idea Group Publishing. pp. 282. ISBN 978-1591404149.
#
# ^ a b c Lita van Wel & Lambèr Royakkers (2004). "Ethical issues in web data mining" (PDF). Ethical Issues in Web Data Mining..
#
# ^ Kirsten Maelstrom; John F. Rodrick; Vladimir Estivill-Castro; Denise de Vries (2007). "Legal and Technical Issues of Privacy Preservation in Data Mining" (PDF). Legal and Technical Issues of Privacy Preservation in Data Mining..
#
# ^ Wang, Yan. "Web Mining and Knowledge Discovery of Usage Patterns".
#
# ^ Kosala, Raymond; Hendrik Blockeel (July 2000). "Web Mining Research: A Survey". SIGKDD Explorations. 2 (1). arXiv:cs.LG/0011033. doi:10.1145/360402.360406.
#
# ^ Galitsky B, Dobrocsi G, de la Rosa JL, Kuznetsov SO.  Using generalization of syntactic parse trees for taxonomy capture on the web. ICCS. 2011;8323.
#
# ^ Speirs, Martha A. (2013). "Data mining for scholarly journals: challenges and solutions for libraries". Cite journal requires |journal= (help)
#
# ^ Dhakal, Kerry (15 April 2019). "Unpaywall". Journal of the Medical Library Association. 107 (2). doi:10.5195/jmla.2019.650. PMC 6466485.
#
#
# Resources[edit]
# This article includes a list of references, but its sources remain unclear because it has insufficient inline citations. Please help to improve this article by introducing more precise citations. (September 2009) (Learn how and when to remove this template message)
# External links[edit]
# The Future of Web Sites = Web Services – (with a section on web scraping)
# Books[edit]
# Zdravko Markov, Daniel T. Larose "Data Mining the Web: Uncovering Patterns in Web Content, Structure, and Usage", Wiley, 2007
# Jesus Mena, "Data Mining Your Website", Digital Press, 1999
# Soumen Chakrabarti, "Mining the Web: Analysis of Hypertext and Semi Structured Data", Morgan Kaufmann, 2002
# Bing Liu, "Web Data Mining: Exploring Hyperlinks, Contents and Usage Data", Springer, 2007
# Advances in Web Mining and Web Usage Analysis 2005 - revised papers from 7 th workshop on Knowledge Discovery on the Web, Olfa Nasraoui, Osmar Zaiane, Myra Spiliopoulou, Bamshad Mobasher, Philip Yu, Brij Masand, Eds., Springer Lecture Notes in Artificial Intelligence, LNAI 4198, 2006
# Web Mining and Web Usage Analysis 2004 - revised papers from 6 th workshop on Knowledge Discovery on the Web, Bamshad Mobasher, Olfa Nasraoui, Bing Liu, Brij Masand, Eds., Springer Lecture Notes in Artificial Intelligence, 2006
# Mike Thelwall, "Link Analysis: An Information Science Approach", 2004, Academic Press
# Bibliographic references[edit]
# Baraglia, R. Silvestri, F. (2007) "Dynamic personalization of web sites without user intervention", In Communications of the ACM 50(2): 63-67
# Cooley, R. Mobasher, B. and Srivastave, J. (1997) “Web Mining: Information and Pattern Discovery on the World Wide Web” In Proceedings of the 9th IEEE International Conference on Tool with Artificial Intelligence
# Cooley, R., Mobasher, B. and Srivastava, J. “Data Preparation for Mining World Wide Web Browsing Patterns”, Journal of Knowledge and Information System, Vol.1, Issue. 1, pp. 5–32, 1999
# Costa, RP and Seco, N. “Hyponymy Extraction and Web Search Behavior Analysis Based On Query Reformulation”, 11th Ibero-American Conference on Artificial Intelligence, 2008 October.
# Kohavi, R., Mason, L. and Zheng, Z. (2004) “Lessons and Challenges from Mining Retail E-commerce Data” Machine Learning, Vol 57, pp. 83–113
# Lillian Clark, I-Hsien Ting, Chris Kimble, Peter Wright, Daniel Kudenko (2006)"Combining ethnographic and clickstream data to identify user Web browsing strategies" Journal of Information Research, Vol. 11 No. 2, January 2006
# Eirinaki, M., Vazirgiannis, M. (2003) "Web Mining for Web Personalization", ACM Transactions on Internet Technology, Vol.3, No.1, February 2003
# Mobasher, B., Cooley, R. and Srivastava, J. (2000) “Automatic Personalization based on web usage Mining” Communications of the ACM, Vol. 43, No.8, pp. 142–151
# Mobasher, B., Dai, H., Luo, T. and Nakagawa, M. (2001) “Effective Personalization Based on Association Rule Discover from Web Usage Data” In Proceedings of WIDM 2001, Atlanta, GA, USA, pp. 9–15
# Nasraoui O., Petenes C.,  "Combining Web Usage Mining and Fuzzy Inference for Website Personalization", in Proc. of WebKDD 2003 – KDD Workshop on Web mining as a Premise to Effective and Intelligent Web Applications, Washington DC, August 2003, p. 37
# Nasraoui O., Frigui H., Joshi A., and Krishnapuram R.,  “Mining Web Access Logs Using Relational Competitive Fuzzy Clustering”, Proceedings of the Eighth International Fuzzy Systems Association Congress, Hsinchu, Taiwan, August 1999
# Nasraoui O., “World Wide Web Personalization,” Invited chapter in “Encyclopedia of Data Mining and Data Warehousing”, J. Wang, Ed, Idea Group, 2005
# Pierrakos, D., Paliouras, G., Papatheodorou, C., Spyropoulos C. D. (2003) “Web usage mining as a tool for personalization: a survey”, User modelling and user adapted interaction journal, Vol.13, Issue 4, pp. 311–372
# I-Hsien Ting, Chris Kimble, Daniel Kudenko (2005) "A Pattern Restore Method for Restoring Missing Patterns in Server Side Clickstream Data"
# I-Hsien Ting, Chris Kimble, Daniel Kudenko (2006) "UBB Mining: Finding Unexpected Browsing Behaviour in Clickstream Data to improve a Web Site’s Design"
# Weichbroth, P., Owoc, M., Pleszkun, M. (2012) "Web User Navigation Patterns Discovery from WWW Server Log Files"
#
#
#
# Retrieved from "https://en.wikipedia.org/w/index.php?title=Web_mining&oldid=965466027"
# Categories: Web analyticsData miningWorld Wide WebHidden categories: CS1 errors: missing periodicalArticles needing cleanup from June 2009All pages needing cleanupCleanup tagged articles without a reason field from June 2009Wikipedia pages needing cleanup from June 2009Articles to be expanded from June 2015All articles to be expandedArticles using small message boxesArticles lacking in-text citations from September 2009All articles lacking in-text citations
#
#
#
#
#
#
# Navigation menu
#
#
#
#
# Personal tools
#
#
#
#
# Not logged inTalkContributionsCreate accountLog in
#
#
#
#
#
#
# Namespaces
#
#
#
#
# ArticleTalk
#
#
#
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
#
#
#
# Views
#
#
#
#
# ReadEditView history
#
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonateWikipedia store
#
#
#
#
#
# Contribute
#
#
#
#
# HelpCommunity portalRecent changesUpload file
#
#
#
#
#
# Tools
#
#
#
#
# What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageWikidata item
#
#
#
#
#
# Print/export
#
#
#
#
# Download as PDFPrintable version
#
#
#
#
#
# Languages
#
#
#
#
# العربيةDeutschEspañolEuskaraفارسیFrançais한국어हिन्दीHrvatskiMagyar日本語PortuguêsРусскийSlovenčinaไทย
# Edit links
#
#
#
#
#
#
#  This page was last edited on 1 July 2020, at 13:43 (UTC).
# Text is available under the Creative Commons Attribution-ShareAlike License;
# additional terms may apply.  By using this site, you agree to the Terms of Use and Privacy Policy. Wikipedia® is a registered trademark of the Wikimedia Foundation, Inc., a non-profit organization.
#
#
# Privacy policy
# About Wikipedia
# Disclaimers
# Contact Wikipedia
# Developers
# Statistics
# Cookie statement
# Mobile view
#
#
#
#
#
#
#
# (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.300","walltime":"0.409","ppvisitednodes":{"value":1424,"limit":1000000},"postexpandincludesize":{"value":36057,"limit":2097152},"templateargumentsize":{"value":3521,"limit":2097152},"expansiondepth":{"value":16,"limit":40},"expensivefunctioncount":{"value":6,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":39313,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  326.954      1 -total"," 50.46%  164.992      1 Template:Reflist"," 32.85%  107.398      1 Template:Cleanup"," 31.35%  102.486      3 Template:Cite_book"," 19.77%   64.635      3 Template:Ambox"," 17.08%   55.853      3 Template:Main_other","  9.72%   31.794      1 Template:Category_handler","  7.67%   25.065      5 Template:Cite_journal","  6.06%   19.827      1 Template:More_footnotes","  5.94%   19.420      1 Template:DMC"]},"scribunto":{"limitreport-timeusage":{"value":"0.134","limit":"10.000"},"limitreport-memusage":{"value":4498450,"limit":52428800}},"cachereport":{"origin":"mw1326","timestamp":"20200803155324","ttl":2592000,"transientcontent":false}}});});
# {"@context":"https:\/\/schema.org","@type":"Article","name":"Web mining","url":"https:\/\/en.wikipedia.org\/wiki\/Web_mining","sameAs":"http:\/\/www.wikidata.org\/entity\/Q785337","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q785337","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2004-07-08T21:37:06Z","dateModified":"2020-07-01T13:43:39Z"}
# (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":94,"wgHostname":"mw1409"});});

# %%
#2

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english')) 
word_tokens = word_tokenize(raw)
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w)
print(len(filtered_sentence))
# Out:
# 4651

# %%
d = {} 
  
for i in filtered_sentence: 
    if i in d: 
        d[i] += 1
    else: 
        d[i] = 1
for key in list(d.keys()):
     print(key, ":", d[key])
# Out:
# Web : 100
# mining : 74
# - : 3
# Wikipedia : 8
# document.documentElement.className= : 1
# '' : 503
# client-js : 1
# ; : 50
# RLCONF= : 1
# { : 45
# `` : 59
# wgBreakFrames : 1
# : : 183
# ! : 18
# 1 : 20
# , : 420
# wgSeparatorTransformTable : 1
# [ : 40
# ] : 40
# wgDigitTransformTable : 1
# wgDefaultDateFormat : 1
# dmy : 1
# wgMonthNames : 1
# January : 2
# February : 2
# March : 1
# April : 2
# May : 1
# June : 11
# July : 3
# August : 3
# September : 5
# October : 2
# November : 1
# December : 1
# wgRequestId : 1
# 8ac52718-95ac-4904-a785-666125065813 : 1
# wgCSPNonce : 1
# wgCanonicalNamespace : 1
# wgCanonicalSpecialPageName : 1
# wgNamespaceNumber : 1
# :0 : 2
# wgPageName : 1
# Web_mining : 2
# wgTitle : 1
# wgCurRevisionId : 1
# :965466027 : 2
# wgRevisionId : 1
# wgArticleId : 1
# :797887 : 2
# wgIsArticle : 1
# 0 : 9
# wgIsRedirect : 1
# wgAction : 1
# view : 7
# wgUserName : 1
# null : 1
# wgUserGroups : 1
# * : 1
# wgCategories : 1
# CS1 : 2
# errors : 2
# missing : 2
# periodical : 1
# Articles : 4
# needing : 6
# cleanup : 7
# 2009 : 6
# All : 3
# pages : 7
# Cleanup : 2
# tagged : 2
# articles : 6
# without : 4
# reason : 3
# field : 2
# expanded : 3
# 2015 : 2
# using : 4
# small : 2
# message : 4
# boxes : 1
# lacking : 4
# in-text : 4
# citations : 6
# analytics : 2
# Data : 18
# World : 7
# Wide : 8
# wgPageContentLanguage : 1
# en : 3
# wgPageContentModel : 1
# wikitext : 1
# wgRelevantPageName : 1
# wgRelevantArticleId : 1
# wgIsProbablyEditable : 1
# wgRelevantPageIsProbablyEditable : 1
# wgRestrictionEdit : 1
# wgRestrictionMove : 1
# wgMediaViewerOnClick : 1
# wgMediaViewerEnabledByDefault : 1
# wgPopupsReferencePreviews : 1
# wgPopupsConflictsWithNavPopupGadget : 1
# wgVisualEditor : 1
# pageLanguageCode : 1
# pageLanguageDir : 1
# ltr : 1
# pageVariantFallbacks : 1
# } : 45
# wgMFDisplayWikibaseDescriptions : 1
# search : 4
# nearby : 1
# watchlist : 1
# tagline : 1
# wgWMESchemaEditAttemptStepOversample : 1
# wgULSCurrentAutonym : 1
# English : 2
# wgNoticeProject : 1
# wikipedia : 1
# wgCentralAuthMobileDomain : 1
# wgEditSubmitButtonLabelPublish : 1
# wgULSPosition : 1
# interlanguage : 1
# wgWikibaseItemId : 1
# Q785337 : 1
# RLSTATE= : 1
# ext.globalCssJs.user.styles : 1
# ready : 13
# site.styles : 1
# noscript : 1
# user.styles : 1
# ext.globalCssJs.user : 1
# user : 11
# user.options : 2
# loading : 1
# ext.cite.styles : 1
# skins.vector.styles.legacy : 1
# mediawiki.toc.styles : 1
# ext.visualEditor.desktopArticleTarget.noscript : 1
# ext.uls.interlanguage : 1
# ext.wikimediaBadges : 1
# wikibase.client.init : 1
# RLPAGEMODULES= : 1
# ext.cite.ux-enhancements : 1
# site : 10
# mediawiki.page.startup : 1
# mediawiki.page.ready : 1
# mediawiki.toc : 1
# skins.vector.legacy.js : 1
# ext.gadget.ReferenceTooltips : 1
# ext.gadget.charinsert : 1
# ext.gadget.extra-toolbar-buttons : 1
# ext.gadget.refToolbar : 1
# ext.gadget.switcher : 1
# ext.centralauth.centralautologin : 1
# mmv.head : 1
# mmv.bootstrap.autostart : 1
# ext.popups : 1
# ext.visualEditor.desktopArticleTarget.init : 1
# ext.visualEditor.targetLoader : 1
# ext.eventLogging : 1
# ext.wikimediaEvents : 1
# ext.navigationTiming : 1
# ext.uls.compactlinks : 1
# ext.uls.interface : 1
# ext.cx.eventlogging.campaigns : 1
# ext.quicksurveys.init : 1
# ext.centralNotice.geoIP : 1
# ext.centralNotice.startUp : 1
# ( : 63
# RLQ=window.RLQ|| : 3
# ) : 63
# .push : 3
# function : 5
# mw.loader.implement : 1
# @ : 7
# 1hzgi : 1
# $ : 1
# jQuery : 1
# require : 3
# module : 1
# /* : 1
# nomin*/mw.user.tokens.set : 1
# patrolToken : 1
# +\\ : 3
# watchToken : 1
# csrfToken : 1
# From : 1
# free : 1
# encyclopedia : 1
# Jump : 2
# navigation : 2
# This : 12
# article : 4
# may : 2
# meet : 1
# 's : 6
# quality : 1
# standards : 2
# . : 158
# No : 2
# specified : 1
# Please : 2
# help : 5
# improve : 3
# Learn : 2
# remove : 2
# template : 2
# application : 6
# data : 44
# techniques : 8
# discover : 4
# patterns : 9
# As : 3
# name : 5
# proposes : 1
# information : 18
# gathered : 1
# web : 28
# It : 4
# makes : 3
# utilization : 1
# automated : 2
# apparatuses : 1
# reveal : 2
# extricate : 1
# servers : 2
# web2 : 1
# reports : 1
# permits : 2
# organizations : 1
# get : 1
# organized : 1
# unstructured : 3
# browser : 1
# activities : 2
# server : 5
# logs : 5
# website : 2
# link : 2
# structure : 27
# page : 10
# content : 15
# different : 6
# sources : 3
# The : 21
# goal : 1
# generate : 2
# structural : 4
# summary : 1
# Technically : 1
# mainly : 1
# focuses : 1
# inner-document : 1
# tries : 2
# hyperlinks : 4
# inter-document : 1
# level : 3
# Based : 3
# topology : 1
# categorize : 3
# similarity : 1
# relationship : 3
# sites : 2
# also : 5
# another : 1
# direction : 1
# – : 5
# discovering : 1
# document : 5
# type : 7
# used : 8
# schema : 3
# would : 1
# good : 1
# purpose : 2
# make : 3
# possible : 1
# compare/integrate : 1
# schemes : 1
# facilitate : 1
# introducing : 2
# database : 4
# accessing : 1
# providing : 2
# reference : 2
# Contents : 2
# types : 4
# 2 : 6
# usage : 20
# 2.1 : 1
# Pros : 2
# 2.2 : 1
# Cons : 2
# 3 : 5
# 4 : 3
# 4.1 : 1
# foreign : 2
# languages : 2
# 4.1.1 : 1
# Chinese : 4
# 5 : 3
# See : 2
# 6 : 5
# References : 2
# 7 : 3
# Resources : 2
# 7.1 : 1
# External : 2
# links : 7
# 7.2 : 1
# Books : 2
# 7.3 : 1
# Bibliographic : 2
# references : 3
# edit : 14
# divided : 2
# three : 1
# general : 3
# categories : 4
# objectives : 1
# Comparison : 1
# IR : 1
# DB : 2
# View : 3
# Unstructured : 1
# Structured : 2
# Semi-structured : 1
# Link : 3
# Interactivity : 1
# Main : 2
# Text : 2
# documents : 11
# Hypertext : 3
# Server : 3
# Browser : 1
# Representation : 1
# Bag : 1
# words : 5
# n-gram : 1
# terms : 2
# phrases : 1
# concepts : 1
# ontology : 1
# Relational : 4
# Edge : 2
# labed : 1
# graph : 5
# Graph : 2
# table : 1
# Method : 2
# Machine : 3
# learning : 2
# Statistical : 2
# including : 2
# NLP : 1
# Proprietary : 2
# algorithms : 5
# Association : 5
# rules : 3
# Application : 3
# Categorization : 2
# Clustering : 3
# Finding : 4
# extract : 2
# text : 4
# frequent : 1
# sub : 1
# structures : 3
# discovery : 2
# Site : 2
# construction : 1
# Adaptation : 1
# management : 3
# interesting : 1
# order : 2
# understand : 1
# better : 4
# serve : 1
# needs : 5
# Web-based : 1
# applications : 6
# Usage : 8
# captures : 1
# identity : 1
# origin : 2
# users : 3
# along : 1
# browsing : 2
# behavior : 2
# classified : 1
# depending : 1
# kind : 1
# considered : 3
# collected : 2
# Typical : 1
# includes : 2
# IP : 1
# address : 2
# access : 3
# time : 2
# Commercial : 1
# significant : 1
# features : 4
# enable : 1
# e-commerce : 2
# built : 1
# top : 1
# little : 1
# effort : 1
# A : 4
# key : 1
# feature : 4
# ability : 1
# track : 1
# various : 1
# kinds : 3
# business : 1
# events : 3
# log : 2
# New : 1
# defined : 3
# logging : 1
# turned : 1
# thus : 2
# generating : 1
# histories : 1
# specially : 1
# Many : 1
# end : 1
# combination : 1
# one : 4
# applied : 3
# Studies : 1
# related : 1
# work : 1
# concerned : 1
# two : 4
# areas : 1
# constraint-based : 1
# developed : 1
# software : 1
# tools : 4
# systems : 2
# Costa : 2
# Seco : 2
# demonstrated : 1
# semantic : 3
# hyponymy : 1
# relationships : 1
# particular : 4
# given : 2
# community : 1
# essentially : 2
# many : 1
# advantages : 1
# technology : 6
# attractive : 1
# corporations : 1
# government : 1
# agencies : 2
# enabled : 1
# personalized : 1
# marketing : 1
# eventually : 1
# results : 2
# higher : 2
# trade : 2
# volumes : 1
# Government : 1
# classify : 1
# threats : 1
# fight : 1
# terrorism : 1
# predicting : 1
# capability : 2
# benefit : 1
# society : 1
# identifying : 2
# criminal : 1
# Companies : 2
# establish : 1
# customer : 7
# understanding : 1
# reacting : 1
# faster : 1
# find : 3
# attract : 1
# retain : 2
# customers : 3
# save : 1
# production : 1
# costs : 1
# utilizing : 1
# acquired : 1
# insight : 1
# requirements : 1
# They : 3
# increase : 1
# profitability : 1
# target : 2
# pricing : 1
# based : 4
# profiles : 2
# created : 1
# even : 1
# might : 6
# default : 1
# competitor : 1
# company : 2
# try : 1
# promotional : 1
# offers : 1
# specific : 4
# reducing : 1
# risk : 1
# losing : 1
# More : 2
# benefits : 2
# particularly : 1
# area : 1
# personalization : 3
# outlined : 1
# frameworks : 1
# probabilistic : 1
# latent : 1
# analysis : 3
# model : 2
# offer : 1
# additional : 3
# pattern : 2
# process : 2
# provides : 1
# relevant : 1
# collaborative : 1
# recommendation : 1
# These : 4
# models : 1
# demonstrate : 1
# problems : 1
# associated : 1
# traditional : 2
# biases : 1
# questions : 1
# regarding : 1
# validity : 2
# since : 1
# obtained : 6
# subjective : 1
# degrade : 1
# There : 2
# elements : 1
# unique : 1
# show : 1
# include : 1
# way : 1
# knowledge : 4
# interpreting : 1
# analyzing : 1
# reasoning : 1
# phase : 1
# create : 1
# issues : 2
# personal : 3
# nature : 1
# cause : 1
# concerns : 1
# criticized : 1
# ethical : 2
# issue : 1
# involving : 1
# invasion : 1
# privacy : 3
# Privacy : 5
# lost : 1
# concerning : 1
# individual : 5
# disseminated : 1
# especially : 1
# occurs : 1
# consent : 1
# analyzed : 1
# made : 2
# anonymous : 4
# clustered : 1
# form : 1
# de-individualize : 1
# judging : 2
# mouse : 1
# clicks : 1
# rather : 1
# De-individualization : 1
# tendency : 1
# treating : 1
# people : 1
# basis : 1
# group : 1
# characteristics : 2
# instead : 1
# merits : 2
# Another : 1
# important : 2
# concern : 1
# companies : 3
# collecting : 1
# use : 5
# totally : 1
# purposes : 1
# violates : 1
# interests : 1
# growing : 1
# trend : 2
# selling : 1
# commodity : 1
# encourages : 1
# owners : 1
# increased : 1
# amount : 1
# captured : 1
# traded : 1
# increasing : 1
# likeliness : 1
# invaded : 1
# buy : 1
# obliged : 1
# authors : 1
# release : 3
# legally : 1
# responsible : 1
# contents : 1
# inaccuracies : 1
# result : 3
# serious : 1
# lawsuits : 1
# law : 1
# preventing : 1
# trading : 1
# Some : 1
# controversial : 2
# attributes : 3
# like : 3
# sex : 1
# race : 2
# religion : 2
# sexual : 2
# orientation : 2
# individuals : 1
# practices : 1
# anti-discrimination : 1
# legislation : 1
# hard : 1
# identify : 4
# strong : 1
# rule : 1
# could : 1
# denial : 1
# service : 1
# privilege : 1
# situation : 1
# avoided : 1
# high : 1
# maintained : 1
# traced : 1
# back : 1
# look : 1
# poses : 1
# threat : 1
# however : 1
# inferred : 1
# combining : 1
# separate : 1
# unscrupulous : 1
# section : 2
# expansion : 1
# You : 1
# adding : 1
# uses : 1
# theory : 1
# analyze : 1
# node : 4
# connection : 1
# According : 1
# Extracting : 1
# hyperlink : 2
# component : 2
# connects : 1
# location : 1
# Mining : 20
# tree-like : 1
# describe : 1
# HTML : 3
# XML : 1
# tag : 1
# terminology : 1
# directed : 1
# representing : 1
# Node : 1
# In : 4
# degree : 2
# number : 3
# pointing : 2
# Out : 1
# generated : 1
# Techniques : 2
# PageRank : 1
# algorithm : 3
# Google : 1
# rank : 2
# Google-founder : 1
# Larry : 1
# Page : 1
# decided : 1
# extraction : 2
# integration : 1
# useful : 3
# heterogeneity : 1
# lack : 1
# much : 1
# ever-expanding : 1
# hypertext : 1
# organization : 3
# indexing : 1
# Internet : 2
# Lycos : 1
# Alta : 1
# Vista : 1
# WebCrawler : 1
# Aliweb : 1
# MetaCrawler : 1
# others : 1
# provide : 3
# comfort : 1
# generally : 1
# filter : 1
# interpret : 1
# factors : 1
# prompted : 1
# researchers : 1
# develop : 1
# intelligent : 2
# retrieval : 3
# agents : 1
# well : 1
# extend : 1
# semi-structured : 3
# available : 2
# agent-based : 1
# approach : 1
# involves : 1
# development : 1
# sophisticated : 1
# AI : 1
# act : 1
# autonomously : 1
# semi-autonomously : 1
# behalf : 1
# organize : 1
# web-based : 1
# differentiated : 1
# points : 1
# 8 : 1
# Information : 6
# Retrieval : 1
# Database : 1
# 9 : 1
# summarized : 1
# research : 1
# works : 3
# done : 1
# shows : 1
# researches : 1
# bag : 1
# statistics : 1
# single : 2
# isolation : 1
# represent : 2
# take : 1
# word : 2
# found : 1
# training : 1
# corpus : 1
# For : 1
# utilize : 1
# inside : 1
# utilized : 1
# representation : 2
# querying : 1
# always : 1
# infer : 1
# transform : 2
# become : 1
# several : 1
# ways : 1
# vector : 2
# space : 2
# typically : 1
# constitute : 1
# whole : 1
# realize : 1
# importance : 1
# To : 1
# resolve : 1
# tf-idf : 1
# Term : 1
# Frequency : 2
# Times : 1
# Inverse : 1
# Document : 1
# introduced : 1
# By : 2
# multi-scanning : 1
# implement : 1
# selection : 1
# Under : 1
# condition : 1
# category : 1
# rarely : 1
# affected : 1
# subset : 1
# needed : 1
# construct : 1
# evaluating : 1
# evaluate : 1
# set : 1
# gain : 1
# cross : 1
# entropy : 1
# mutual : 1
# odds : 1
# ratio : 1
# usually : 1
# classifier : 1
# methods : 2
# similar : 1
# usual : 1
# evaluative : 1
# classification : 1
# accuracy : 1
# precision : 1
# recall : 1
# score : 1
# pipeline : 1
# portals : 1
# confirmation : 1
# verification : 1
# integrity : 1
# building : 1
# taxonomies : 1
# generation : 1
# opinion : 1
# 10 : 1
# complement : 1
# structured : 1
# transmitted : 1
# open : 4
# protocols : 1
# OAI-PMH : 1
# example : 1
# aggregation : 1
# academic : 2
# publications : 1
# 11 : 2
# mined : 1
# versions : 1
# mix : 1
# source : 1
# databases : 1
# Unpaywall : 2
# 12 : 1
# language : 1
# code : 4
# complicated : 1
# compared : 1
# GB : 1
# Big5 : 1
# HZ : 1
# common : 1
# codes : 1
# Before : 1
# standard : 1
# inner : 1
# intelligence : 1
# scraping : 2
# ^ : 12
# Galitsky : 2
# B. : 5
# Dobrocsi : 2
# G. : 2
# de : 3
# la : 2
# Rosa : 2
# J. : 2
# L. : 2
# Kuznetsov : 2
# S. : 1
# O.. : 1
# Using : 3
# generalization : 2
# syntactic : 2
# parse : 2
# trees : 2
# taxonomy : 2
# capture : 2
# ICCS : 2
# 2011 : 2
# 8323 : 2
# Weichbroth : 2
# et : 1
# al : 1
# Ngu : 1
# Anne : 1
# Kitsuregawa : 1
# Masaru : 1
# Chung : 1
# Jen-Yao : 1
# Neuhold : 1
# Erich : 1
# Sheng : 1
# Quan : 1
# 2005 : 6
# Systems : 2
# Engineering : 1
# WISE : 1
# Berlin : 2
# Springer : 5
# pp : 8
# 15 : 2
# ISBN : 3
# 9783540300175..mw-parser-output : 1
# cite.citation : 1
# font-style : 1
# inherit : 6
# .mw-parser-output : 26
# .citation : 6
# q : 1
# quotes : 1
# \ : 2
# ' : 2
# .id-lock-free : 1
# .cs1-lock-free : 1
# background-image : 8
# url : 10
# //upload.wikimedia.org/wikipedia/commons/thumb/6/65/Lock-green.svg/9px-Lock-green.svg.png : 1
# linear-gradient : 4
# transparent : 8
# //upload.wikimedia.org/wikipedia/commons/6/65/Lock-green.svg : 1
# background-repeat : 4
# no-repeat : 4
# background-size:9px : 3
# background-position : 4
# right : 4
# .1em : 4
# center : 4
# .id-lock-limited : 1
# .id-lock-registration : 1
# .cs1-lock-limited : 1
# .cs1-lock-registration : 1
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Lock-gray-alt-2.svg/9px-Lock-gray-alt-2.svg.png : 1
# //upload.wikimedia.org/wikipedia/commons/d/d6/Lock-gray-alt-2.svg : 1
# .id-lock-subscription : 1
# .cs1-lock-subscription : 1
# //upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Lock-red-alt-2.svg/9px-Lock-red-alt-2.svg.png : 1
# //upload.wikimedia.org/wikipedia/commons/a/aa/Lock-red-alt-2.svg : 1
# .cs1-subscription : 3
# .cs1-registration : 3
# color : 3
# # : 2
# 555 : 1
# span : 2
# border-bottom:1px : 1
# dotted : 1
# cursor : 1
# .cs1-ws-icon : 1
# //upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/12px-Wikisource-logo.svg.png : 1
# //upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg : 1
# background-size:12px : 1
# code.cs1-code : 1
# background : 1
# border : 1
# padding : 1
# .cs1-hidden-error : 1
# display : 2
# none : 2
# font-size:100 : 2
# % : 13
# .cs1-visible-error : 1
# .cs1-maint : 1
# 33aa33 : 1
# margin-left:0.3em : 1
# .cs1-format : 1
# font-size:95 : 1
# .cs1-kern-left : 1
# .cs1-kern-wl-left : 1
# padding-left:0.2em : 1
# .cs1-kern-right : 1
# .cs1-kern-wl-right : 1
# padding-right:0.2em : 1
# .mw-selflink : 1
# font-weight : 1
# Bauknecht : 1
# Kurt : 1
# Madria : 1
# Sanjay : 1
# Pernul : 1
# Gunther : 1
# 2000 : 5
# Electronic : 1
# Commerce : 1
# Technologies : 1
# First : 1
# International : 3
# Conference : 3
# EC-Web : 1
# London : 1
# UK : 1
# 4-6 : 1
# Proceedings : 4
# 165 : 1
# 978-3540679813 : 1
# Scime : 1
# Anthony : 1
# Applications : 2
# Hershey : 1
# PA : 1
# Idea : 2
# Group : 2
# Publishing : 1
# 282 : 1
# 978-1591404149 : 1
# b : 1
# c : 1
# Lita : 1
# van : 1
# Wel : 1
# & : 2
# Lambèr : 1
# Royakkers : 1
# 2004 : 4
# Ethical : 2
# PDF : 2
# Issues : 3
# Mining.. : 2
# Kirsten : 1
# Maelstrom : 1
# John : 1
# F. : 2
# Rodrick : 1
# Vladimir : 1
# Estivill-Castro : 1
# Denise : 1
# Vries : 1
# 2007 : 4
# Legal : 2
# Technical : 2
# Preservation : 2
# Wang : 2
# Yan : 1
# Knowledge : 4
# Discovery : 5
# Patterns : 5
# Kosala : 1
# Raymond : 1
# Hendrik : 1
# Blockeel : 1
# Research : 2
# Survey : 1
# SIGKDD : 1
# Explorations : 1
# arXiv : 1
# cs.LG/0011033 : 1
# doi:10.1145/360402.360406 : 1
# B : 1
# G : 1
# JL : 1
# SO : 1
# Speirs : 1
# Martha : 1
# 2013 : 1
# scholarly : 1
# journals : 1
# challenges : 1
# solutions : 1
# libraries : 1
# Cite : 1
# journal : 2
# requires : 1
# |journal= : 1
# Dhakal : 1
# Kerry : 1
# 2019 : 1
# Journal : 3
# Medical : 1
# Library : 1
# 107 : 1
# doi:10.5195/jmla.2019.650 : 1
# PMC : 1
# 6466485 : 1
# list : 1
# remain : 1
# unclear : 1
# insufficient : 1
# inline : 1
# precise : 1
# Future : 1
# Sites : 1
# = : 1
# Services : 1
# Zdravko : 1
# Markov : 1
# Daniel : 4
# T. : 2
# Larose : 1
# Uncovering : 1
# Content : 1
# Structure : 1
# Wiley : 1
# Jesus : 1
# Mena : 1
# Your : 1
# Website : 2
# Digital : 1
# Press : 2
# 1999 : 3
# Soumen : 1
# Chakrabarti : 1
# Analysis : 5
# Semi : 1
# Morgan : 1
# Kaufmann : 1
# 2002 : 1
# Bing : 2
# Liu : 2
# Exploring : 1
# Hyperlinks : 1
# Advances : 1
# revised : 2
# papers : 2
# th : 2
# workshop : 2
# Olfa : 2
# Nasraoui : 5
# Osmar : 1
# Zaiane : 1
# Myra : 1
# Spiliopoulou : 1
# Bamshad : 2
# Mobasher : 6
# Philip : 1
# Yu : 1
# Brij : 2
# Masand : 2
# Eds. : 2
# Lecture : 2
# Notes : 2
# Artificial : 4
# Intelligence : 4
# LNAI : 1
# 4198 : 1
# 2006 : 5
# Mike : 1
# Thelwall : 1
# An : 1
# Science : 1
# Approach : 1
# Academic : 1
# Baraglia : 1
# R. : 6
# Silvestri : 1
# Dynamic : 1
# intervention : 1
# Communications : 2
# ACM : 3
# 50 : 1
# 63-67 : 1
# Cooley : 3
# Srivastave : 1
# J : 3
# 1997 : 1
# “ : 10
# Pattern : 2
# ” : 10
# 9th : 1
# IEEE : 1
# Tool : 1
# Srivastava : 2
# Preparation : 1
# Browsing : 2
# System : 1
# Vol.1 : 1
# Issue : 2
# 5–32 : 1
# RP : 1
# N. : 1
# Hyponymy : 1
# Extraction : 1
# Search : 2
# Behavior : 1
# On : 1
# Query : 1
# Reformulation : 1
# 11th : 1
# Ibero-American : 1
# 2008 : 1
# Kohavi : 1
# Mason : 1
# Zheng : 1
# Z : 1
# Lessons : 1
# Challenges : 1
# Retail : 1
# E-commerce : 1
# Learning : 1
# Vol : 3
# 57 : 1
# 83–113 : 1
# Lillian : 1
# Clark : 1
# I-Hsien : 3
# Ting : 3
# Chris : 3
# Kimble : 3
# Peter : 1
# Wright : 1
# Kudenko : 3
# Combining : 2
# ethnographic : 1
# clickstream : 1
# strategies : 1
# Eirinaki : 1
# M. : 5
# Vazirgiannis : 1
# 2003 : 5
# Personalization : 5
# Transactions : 1
# Technology : 1
# Vol.3 : 1
# No.1 : 1
# Automatic : 1
# 43 : 1
# No.8 : 1
# 142–151 : 1
# Dai : 1
# H. : 2
# Luo : 1
# Nakagawa : 1
# 2001 : 2
# Effective : 2
# Rule : 1
# Discover : 1
# WIDM : 1
# Atlanta : 1
# GA : 1
# USA : 1
# 9–15 : 1
# O. : 3
# Petenes : 1
# C. : 3
# Fuzzy : 3
# Inference : 1
# Proc : 1
# WebKDD : 1
# KDD : 1
# Workshop : 1
# Premise : 1
# Intelligent : 1
# Washington : 1
# DC : 1
# p. : 1
# 37 : 1
# Frigui : 1
# Joshi : 1
# A. : 1
# Krishnapuram : 1
# Access : 1
# Logs : 1
# Competitive : 1
# Eighth : 1
# Congress : 1
# Hsinchu : 1
# Taiwan : 1
# Invited : 1
# chapter : 1
# Encyclopedia : 1
# Warehousing : 1
# Ed : 1
# Pierrakos : 1
# D. : 2
# Paliouras : 1
# Papatheodorou : 1
# Spyropoulos : 1
# tool : 1
# survey : 1
# User : 2
# modelling : 1
# adapted : 1
# interaction : 1
# Vol.13 : 1
# 311–372 : 1
# Restore : 1
# Restoring : 1
# Missing : 1
# Side : 1
# Clickstream : 2
# UBB : 1
# Unexpected : 1
# Behaviour : 1
# ’ : 1
# Design : 1
# P. : 1
# Owoc : 1
# Pleszkun : 1
# 2012 : 1
# Navigation : 3
# WWW : 1
# Log : 1
# Files : 1
# Retrieved : 1
# https : 4
# //en.wikipedia.org/w/index.php : 1
# ? : 1
# title=Web_mining : 1
# oldid=965466027 : 1
# Categories : 1
# analyticsData : 1
# miningWorld : 1
# WebHidden : 1
# periodicalArticles : 1
# 2009All : 2
# cleanupCleanup : 1
# 2009Wikipedia : 1
# 2009Articles : 1
# 2015All : 1
# expandedArticles : 1
# boxesArticles : 1
# menu : 1
# Personal : 1
# Not : 1
# logged : 1
# inTalkContributionsCreate : 1
# accountLog : 1
# Namespaces : 1
# ArticleTalk : 1
# Variants : 1
# Views : 1
# ReadEditView : 1
# history : 1
# pageContentsCurrent : 1
# eventsRandom : 1
# articleAbout : 1
# WikipediaContact : 1
# usDonateWikipedia : 1
# store : 1
# Contribute : 1
# HelpCommunity : 1
# portalRecent : 1
# changesUpload : 2
# file : 1
# Tools : 1
# What : 1
# hereRelated : 1
# fileSpecial : 1
# pagesPermanent : 1
# linkPage : 1
# informationCite : 1
# pageWikidata : 1
# item : 1
# Print/export : 1
# Download : 1
# PDFPrintable : 1
# version : 1
# Languages : 1
# العربيةDeutschEspañolEuskaraفارسیFrançais한국어हिन्दीHrvatskiMagyar日本語PortuguêsРусскийSlovenčinaไทย : 1
# Edit : 1
# last : 1
# edited : 1
# 2020 : 1
# 13:43 : 1
# UTC : 1
# Creative : 1
# Commons : 1
# Attribution-ShareAlike : 1
# License : 1
# apply : 1
# agree : 1
# Terms : 1
# Use : 1
# Policy : 1
# Wikipedia® : 1
# registered : 1
# trademark : 1
# Wikimedia : 3
# Foundation : 2
# Inc. : 2
# non-profit : 1
# policy : 1
# About : 1
# Disclaimers : 1
# Contact : 1
# Developers : 1
# Statistics : 1
# Cookie : 1
# statement : 1
# Mobile : 1
# mw.config.set : 2
# wgPageParseReport : 1
# limitreport : 1
# cputime : 1
# 0.300 : 1
# walltime : 1
# 0.409 : 1
# ppvisitednodes : 1
# value : 10
# :1424 : 1
# limit : 10
# :1000000 : 1
# postexpandincludesize : 1
# :36057 : 1
# :2097152 : 2
# templateargumentsize : 1
# :3521 : 1
# expansiondepth : 1
# :16 : 1
# :40 : 1
# expensivefunctioncount : 1
# :6 : 1
# :500 : 1
# unstrip-depth : 1
# :1 : 1
# :20 : 1
# unstrip-size : 1
# :39313 : 1
# :5000000 : 1
# entityaccesscount : 1
# :400 : 1
# timingprofile : 1
# 100.00 : 1
# 326.954 : 1
# -total : 1
# 50.46 : 1
# 164.992 : 1
# Template : 9
# Reflist : 1
# 32.85 : 1
# 107.398 : 1
# 31.35 : 1
# 102.486 : 1
# Cite_book : 1
# 19.77 : 1
# 64.635 : 1
# Ambox : 1
# 17.08 : 1
# 55.853 : 1
# Main_other : 1
# 9.72 : 1
# 31.794 : 1
# Category_handler : 1
# 7.67 : 1
# 25.065 : 1
# Cite_journal : 1
# 6.06 : 1
# 19.827 : 1
# More_footnotes : 1
# 5.94 : 1
# 19.420 : 1
# DMC : 1
# scribunto : 1
# limitreport-timeusage : 1
# 0.134 : 1
# 10.000 : 1
# limitreport-memusage : 1
# :4498450 : 1
# :52428800 : 1
# cachereport : 1
# mw1326 : 1
# timestamp : 1
# 20200803155324 : 1
# ttl : 1
# :2592000 : 1
# transientcontent : 1
# false : 1
# context : 1
# \/\/schema.org : 1
# Article : 1
# \/\/en.wikipedia.org\/wiki\/Web_mining : 1
# sameAs : 1
# http : 2
# \/\/www.wikidata.org\/entity\/Q785337 : 2
# mainEntity : 1
# author : 1
# Organization : 2
# Contributors : 1
# projects : 1
# publisher : 1
# logo : 1
# ImageObject : 1
# \/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png : 1
# datePublished : 1
# 2004-07-08T21:37:06Z : 1
# dateModified : 1
# 2020-07-01T13:43:39Z : 1
# wgBackendResponseTime : 1
# :94 : 1
# wgHostname : 1
# mw1409 : 1

# %%
#3

# %%
STOP_WORDS = set(stopwords.words('english'))
STOP_WORDS.add('-')
STOP_WORDS.add(',')
STOP_WORDS.add("\'s")
STOP_WORDS.add("\'")
STOP_WORDS.add('.')
STOP_WORDS.add(',')
STOP_WORDS.add('(')
STOP_WORDS.add(')')
STOP_WORDS.add('[')
STOP_WORDS.add(']')
STOP_WORDS.add(';')
STOP_WORDS.add(':')
STOP_WORDS.add('^')
STOP_WORDS.add('..')
STOP_WORDS.add('&')
STOP_WORDS.add('=')
STOP_WORDS.add('?')

word_tokens = word_tokenize(raw)
filtered_sentence1 = [w for w in word_tokens if not w in STOP_WORDS]
print(len(filtered_sentence1))
# Out:
# 3607

# %%
#4

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
ps = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer() 
stems = []
lemma = []
for w in filtered_sentence1:
    print(w,"-",ps.stem(w), " - ", lemmatizer.lemmatize(w))   
    stems.append(ps.stem(w))
    lemma.append(lemmatizer.lemmatize(w))
# Out:
# Web - web  -  Web
# mining - mine  -  mining
# Wikipedia - wikipedia  -  Wikipedia
# document.documentElement.className= - document.documentelement.classname=  -  document.documentElement.className=
# '' - ''  -  ''
# client-js - client-j  -  client-js
# '' - ''  -  ''
# RLCONF= - rlconf=  -  RLCONF=
# { - {  -  {
# `` - ``  -  ``
# wgBreakFrames - wgbreakfram  -  wgBreakFrames
# '' - ''  -  ''
# ! - !  -  !
# 1 - 1  -  1
# '' - ''  -  ''
# wgSeparatorTransformTable - wgseparatortransformt  -  wgSeparatorTransformTable
# '' - ''  -  ''
# `` - ``  -  ``
# '' - ''  -  ''
# '' - ''  -  ''
# '' - ''  -  ''
# '' - ''  -  ''
# wgDigitTransformTable - wgdigittransformt  -  wgDigitTransformTable
# '' - ''  -  ''
# `` - ``  -  ``
# '' - ''  -  ''
# '' - ''  -  ''
# '' - ''  -  ''
# '' - ''  -  ''
# wgDefaultDateFormat - wgdefaultdateformat  -  wgDefaultDateFormat
# '' - ''  -  ''
# '' - ''  -  ''
# dmy - dmi  -  dmy
# '' - ''  -  ''
# '' - ''  -  ''
# wgMonthNames - wgmonthnam  -  wgMonthNames
# '' - ''  -  ''
# `` - ``  -  ``
# '' - ''  -  ''
# '' - ''  -  ''
# January - januari  -  January
# '' - ''  -  ''
# '' - ''  -  ''
# February - februari  -  February
# '' - ''  -  ''
# '' - ''  -  ''
# March - march  -  March
# '' - ''  -  ''
# '' - ''  -  ''
# April - april  -  April
# '' - ''  -  ''
# '' - ''  -  ''
# May - may  -  May
# '' - ''  -  ''
# '' - ''  -  ''
# June - june  -  June
# '' - ''  -  ''
# '' - ''  -  ''
# July - juli  -  July
# '' - ''  -  ''
# '' - ''  -  ''
# August - august  -  August
# '' - ''  -  ''
# '' - ''  -  ''
# September - septemb  -  September
# '' - ''  -  ''
# '' - ''  -  ''
# October - octob  -  October
# '' - ''  -  ''
# '' - ''  -  ''
# November - novemb  -  November
# '' - ''  -  ''
# '' - ''  -  ''
# December - decemb  -  December
# '' - ''  -  ''
# '' - ''  -  ''
# wgRequestId - wgrequestid  -  wgRequestId
# '' - ''  -  ''
# '' - ''  -  ''
# 8ac52718-95ac-4904-a785-666125065813 - 8ac52718-95ac-4904-a785-666125065813  -  8ac52718-95ac-4904-a785-666125065813
# '' - ''  -  ''
# '' - ''  -  ''
# wgCSPNonce - wgcspnonc  -  wgCSPNonce
# '' - ''  -  ''
# ! - !  -  !
# 1 - 1  -  1
# '' - ''  -  ''
# wgCanonicalNamespace - wgcanonicalnamespac  -  wgCanonicalNamespace
# '' - ''  -  ''
# '' - ''  -  ''
# '' - ''  -  ''
# '' - ''  -  ''
# wgCanonicalSpecialPageName - wgcanonicalspecialpagenam  -  wgCanonicalSpecialPageName
# '' - ''  -  ''
# ! - !  -  !
# 1 - 1  -  1
# '' - ''  -  ''
# wgNamespaceNumber - wgnamespacenumb  -  wgNamespaceNumber
# '' - ''  -  ''
# :0 - :0  -  :0
# '' - ''  -  ''
# wgPageName - wgpagenam  -  wgPageName
# '' - ''  -  ''
# '' - ''  -  ''
# Web_mining - web_min  -  Web_mining
# '' - ''  -  ''
# '' - ''  -  ''
# wgTitle - wgtitl  -  wgTitle
# '' - ''  -  ''
# '' - ''  -  ''
# Web - web  -  Web
# mining - mine  -  mining
# '' - ''  -  ''
# '' - ''  -  ''
# wgCurRevisionId - wgcurrevisionid  -  wgCurRevisionId
# '' - ''  -  ''
# :965466027 - :965466027  -  :965466027
# '' - ''  -  ''
# wgRevisionId - wgrevisionid  -  wgRevisionId
# '' - ''  -  ''
# :965466027 - :965466027  -  :965466027
# '' - ''  -  ''
# wgArticleId - wgarticleid  -  wgArticleId
# '' - ''  -  ''
# :797887 - :797887  -  :797887
# '' - ''  -  ''
# wgIsArticle - wgisarticl  -  wgIsArticle
# '' - ''  -  ''
# ! - !  -  !
# 0 - 0  -  0
# '' - ''  -  ''
# wgIsRedirect - wgisredirect  -  wgIsRedirect
# '' - ''  -  ''
# ! - !  -  !
# 1 - 1  -  1
# '' - ''  -  ''
# wgAction - wgaction  -  wgAction
# '' - ''  -  ''
# '' - ''  -  ''
# view - view  -  view
# '' - ''  -  ''
# '' - ''  -  ''
# wgUserName - wgusernam  -  wgUserName
# '' - ''  -  ''
# null - null  -  null
# '' - ''  -  ''
# wgUserGroups - wgusergroup  -  wgUserGroups
# '' - ''  -  ''
# `` - ``  -  ``
# * - *  -  *
# '' - ''  -  ''
# '' - ''  -  ''
# wgCategories - wgcategori  -  wgCategories
# '' - ''  -  ''
# `` - ``  -  ``
# CS1 - cs1  -  CS1
# errors - error  -  error
# missing - miss  -  missing
# periodical - period  -  periodical
# '' - ''  -  ''
# '' - ''  -  ''
# Articles - articl  -  Articles
# needing - need  -  needing
# cleanup - cleanup  -  cleanup
# June - june  -  June
# 2009 - 2009  -  2009
# '' - ''  -  ''
# '' - ''  -  ''
# All - all  -  All
# pages - page  -  page
# needing - need  -  needing
# cleanup - cleanup  -  cleanup
# '' - ''  -  ''
# '' - ''  -  ''
# Cleanup - cleanup  -  Cleanup
# tagged - tag  -  tagged
# articles - articl  -  article
# without - without  -  without
# reason - reason  -  reason
# field - field  -  field
# June - june  -  June
# 2009 - 2009  -  2009
# '' - ''  -  ''
# '' - ''  -  ''
# Wikipedia - wikipedia  -  Wikipedia
# pages - page  -  page
# needing - need  -  needing
# cleanup - cleanup  -  cleanup
# June - june  -  June
# 2009 - 2009  -  2009
# '' - ''  -  ''
# '' - ''  -  ''
# Articles - articl  -  Articles
# expanded - expand  -  expanded
# June - june  -  June
# 2015 - 2015  -  2015
# '' - ''  -  ''
# '' - ''  -  ''
# All - all  -  All
# articles - articl  -  article
# expanded - expand  -  expanded
# '' - ''  -  ''
# '' - ''  -  ''
# Articles - articl  -  Articles
# using - use  -  using
# small - small  -  small
# message - messag  -  message
# boxes - box  -  box
# '' - ''  -  ''
# '' - ''  -  ''
# Articles - articl  -  Articles
# lacking - lack  -  lacking
# in-text - in-text  -  in-text
# citations - citat  -  citation
# September - septemb  -  September
# 2009 - 2009  -  2009
# '' - ''  -  ''
# '' - ''  -  ''
# All - all  -  All
# articles - articl  -  article
# lacking - lack  -  lacking
# in-text - in-text  -  in-text
# citations - citat  -  citation
# '' - ''  -  ''
# '' - ''  -  ''
# Web - web  -  Web
# analytics - analyt  -  analytics
# '' - ''  -  ''
# '' - ''  -  ''
# Data - data  -  Data
# mining - mine  -  mining
# '' - ''  -  ''
# '' - ''  -  ''
# World - world  -  World
# Wide - wide  -  Wide
# Web - web  -  Web
# '' - ''  -  ''
# '' - ''  -  ''
# wgPageContentLanguage - wgpagecontentlanguag  -  wgPageContentLanguage
# '' - ''  -  ''
# '' - ''  -  ''
# en - en  -  en
# '' - ''  -  ''
# '' - ''  -  ''
# wgPageContentModel - wgpagecontentmodel  -  wgPageContentModel
# '' - ''  -  ''
# '' - ''  -  ''
# wikitext - wikitext  -  wikitext
# '' - ''  -  ''
# '' - ''  -  ''
# wgRelevantPageName - wgrelevantpagenam  -  wgRelevantPageName
# '' - ''  -  ''
# '' - ''  -  ''
# Web_mining - web_min  -  Web_mining
# '' - ''  -  ''
# '' - ''  -  ''
# wgRelevantArticleId - wgrelevantarticleid  -  wgRelevantArticleId
# '' - ''  -  ''
# :797887 - :797887  -  :797887
# '' - ''  -  ''
# wgIsProbablyEditable - wgisprobablyedit  -  wgIsProbablyEditable
# '' - ''  -  ''
# ! - !  -  !
# 0 - 0  -  0
# '' - ''  -  ''
# wgRelevantPageIsProbablyEditable - wgrelevantpageisprobablyedit  -  wgRelevantPageIsProbablyEditable
# '' - ''  -  ''
# ! - !  -  !
# 0 - 0  -  0
# '' - ''  -  ''
# wgRestrictionEdit - wgrestrictionedit  -  wgRestrictionEdit
# '' - ''  -  ''
# '' - ''  -  ''
# wgRestrictionMove - wgrestrictionmov  -  wgRestrictionMove
# '' - ''  -  ''
# '' - ''  -  ''
# wgMediaViewerOnClick - wgmediavieweronclick  -  wgMediaViewerOnClick
# '' - ''  -  ''
# ! - !  -  !
# 0 - 0  -  0
# '' - ''  -  ''
# wgMediaViewerEnabledByDefault - wgmediaviewerenabledbydefault  -  wgMediaViewerEnabledByDefault
# '' - ''  -  ''
# ! - !  -  !
# 0 - 0  -  0
# '' - ''  -  ''
# wgPopupsReferencePreviews - wgpopupsreferencepreview  -  wgPopupsReferencePreviews
# '' - ''  -  ''
# ! - !  -  !
# 1 - 1  -  1
# '' - ''  -  ''
# wgPopupsConflictsWithNavPopupGadget - wgpopupsconflictswithnavpopupgadget  -  wgPopupsConflictsWithNavPopupGadget
# '' - ''  -  ''
# ! - !  -  !
# 1 - 1  -  1
# '' - ''  -  ''
# wgVisualEditor - wgvisualeditor  -  wgVisualEditor
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# pageLanguageCode - pagelanguagecod  -  pageLanguageCode
# '' - ''  -  ''
# '' - ''  -  ''
# en - en  -  en
# '' - ''  -  ''
# '' - ''  -  ''
# pageLanguageDir - pagelanguagedir  -  pageLanguageDir
# '' - ''  -  ''
# '' - ''  -  ''
# ltr - ltr  -  ltr
# '' - ''  -  ''
# '' - ''  -  ''
# pageVariantFallbacks - pagevariantfallback  -  pageVariantFallbacks
# '' - ''  -  ''
# '' - ''  -  ''
# en - en  -  en
# '' - ''  -  ''
# } - }  -  }
# '' - ''  -  ''
# wgMFDisplayWikibaseDescriptions - wgmfdisplaywikibasedescript  -  wgMFDisplayWikibaseDescriptions
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# search - search  -  search
# '' - ''  -  ''
# ! - !  -  !
# 0 - 0  -  0
# '' - ''  -  ''
# nearby - nearbi  -  nearby
# '' - ''  -  ''
# ! - !  -  !
# 0 - 0  -  0
# '' - ''  -  ''
# watchlist - watchlist  -  watchlist
# '' - ''  -  ''
# ! - !  -  !
# 0 - 0  -  0
# '' - ''  -  ''
# tagline - taglin  -  tagline
# '' - ''  -  ''
# ! - !  -  !
# 1 - 1  -  1
# } - }  -  }
# '' - ''  -  ''
# wgWMESchemaEditAttemptStepOversample - wgwmeschemaeditattemptstepoversampl  -  wgWMESchemaEditAttemptStepOversample
# '' - ''  -  ''
# ! - !  -  !
# 1 - 1  -  1
# '' - ''  -  ''
# wgULSCurrentAutonym - wgulscurrentautonym  -  wgULSCurrentAutonym
# '' - ''  -  ''
# '' - ''  -  ''
# English - english  -  English
# '' - ''  -  ''
# '' - ''  -  ''
# wgNoticeProject - wgnoticeproject  -  wgNoticeProject
# '' - ''  -  ''
# '' - ''  -  ''
# wikipedia - wikipedia  -  wikipedia
# '' - ''  -  ''
# '' - ''  -  ''
# wgCentralAuthMobileDomain - wgcentralauthmobiledomain  -  wgCentralAuthMobileDomain
# '' - ''  -  ''
# ! - !  -  !
# 1 - 1  -  1
# '' - ''  -  ''
# wgEditSubmitButtonLabelPublish - wgeditsubmitbuttonlabelpublish  -  wgEditSubmitButtonLabelPublish
# '' - ''  -  ''
# ! - !  -  !
# 0 - 0  -  0
# '' - ''  -  ''
# wgULSPosition - wgulsposit  -  wgULSPosition
# '' - ''  -  ''
# '' - ''  -  ''
# interlanguage - interlanguag  -  interlanguage
# '' - ''  -  ''
# '' - ''  -  ''
# wgWikibaseItemId - wgwikibaseitemid  -  wgWikibaseItemId
# '' - ''  -  ''
# '' - ''  -  ''
# Q785337 - q785337  -  Q785337
# '' - ''  -  ''
# } - }  -  }
# RLSTATE= - rlstate=  -  RLSTATE=
# { - {  -  {
# `` - ``  -  ``
# ext.globalCssJs.user.styles - ext.globalcssjs.user.styl  -  ext.globalCssJs.user.styles
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# site.styles - site.styl  -  site.styles
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# noscript - noscript  -  noscript
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# user.styles - user.styl  -  user.styles
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# ext.globalCssJs.user - ext.globalcssjs.us  -  ext.globalCssJs.user
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# user - user  -  user
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# user.options - user.opt  -  user.options
# '' - ''  -  ''
# '' - ''  -  ''
# loading - load  -  loading
# '' - ''  -  ''
# '' - ''  -  ''
# ext.cite.styles - ext.cite.styl  -  ext.cite.styles
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# skins.vector.styles.legacy - skins.vector.styles.legaci  -  skins.vector.styles.legacy
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# mediawiki.toc.styles - mediawiki.toc.styl  -  mediawiki.toc.styles
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# ext.visualEditor.desktopArticleTarget.noscript - ext.visualeditor.desktoparticletarget.noscript  -  ext.visualEditor.desktopArticleTarget.noscript
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# ext.uls.interlanguage - ext.uls.interlanguag  -  ext.uls.interlanguage
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# ext.wikimediaBadges - ext.wikimediabadg  -  ext.wikimediaBadges
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# '' - ''  -  ''
# wikibase.client.init - wikibase.client.init  -  wikibase.client.init
# '' - ''  -  ''
# '' - ''  -  ''
# ready - readi  -  ready
# '' - ''  -  ''
# } - }  -  }
# RLPAGEMODULES= - rlpagemodules=  -  RLPAGEMODULES=
# `` - ``  -  ``
# ext.cite.ux-enhancements - ext.cite.ux-enhanc  -  ext.cite.ux-enhancements
# '' - ''  -  ''
# '' - ''  -  ''
# site - site  -  site
# '' - ''  -  ''
# '' - ''  -  ''
# mediawiki.page.startup - mediawiki.page.startup  -  mediawiki.page.startup
# '' - ''  -  ''
# '' - ''  -  ''
# mediawiki.page.ready - mediawiki.page.readi  -  mediawiki.page.ready
# '' - ''  -  ''
# '' - ''  -  ''
# mediawiki.toc - mediawiki.toc  -  mediawiki.toc
# '' - ''  -  ''
# '' - ''  -  ''
# skins.vector.legacy.js - skins.vector.legacy.j  -  skins.vector.legacy.js
# '' - ''  -  ''
# '' - ''  -  ''
# ext.gadget.ReferenceTooltips - ext.gadget.referencetooltip  -  ext.gadget.ReferenceTooltips
# '' - ''  -  ''
# '' - ''  -  ''
# ext.gadget.charinsert - ext.gadget.charinsert  -  ext.gadget.charinsert
# '' - ''  -  ''
# '' - ''  -  ''
# ext.gadget.extra-toolbar-buttons - ext.gadget.extra-toolbar-button  -  ext.gadget.extra-toolbar-buttons
# '' - ''  -  ''
# '' - ''  -  ''
# ext.gadget.refToolbar - ext.gadget.reftoolbar  -  ext.gadget.refToolbar
# '' - ''  -  ''
# '' - ''  -  ''
# ext.gadget.switcher - ext.gadget.switch  -  ext.gadget.switcher
# '' - ''  -  ''
# '' - ''  -  ''
# ext.centralauth.centralautologin - ext.centralauth.centralautologin  -  ext.centralauth.centralautologin
# '' - ''  -  ''
# '' - ''  -  ''
# mmv.head - mmv.head  -  mmv.head
# '' - ''  -  ''
# '' - ''  -  ''
# mmv.bootstrap.autostart - mmv.bootstrap.autostart  -  mmv.bootstrap.autostart
# '' - ''  -  ''
# '' - ''  -  ''
# ext.popups - ext.popup  -  ext.popups
# '' - ''  -  ''
# '' - ''  -  ''
# ext.visualEditor.desktopArticleTarget.init - ext.visualeditor.desktoparticletarget.init  -  ext.visualEditor.desktopArticleTarget.init
# '' - ''  -  ''
# '' - ''  -  ''
# ext.visualEditor.targetLoader - ext.visualeditor.targetload  -  ext.visualEditor.targetLoader
# '' - ''  -  ''
# '' - ''  -  ''
# ext.eventLogging - ext.eventlog  -  ext.eventLogging
# '' - ''  -  ''
# '' - ''  -  ''
# ext.wikimediaEvents - ext.wikimediaev  -  ext.wikimediaEvents
# '' - ''  -  ''
# '' - ''  -  ''
# ext.navigationTiming - ext.navigationtim  -  ext.navigationTiming
# '' - ''  -  ''
# '' - ''  -  ''
# ext.uls.compactlinks - ext.uls.compactlink  -  ext.uls.compactlinks
# '' - ''  -  ''
# '' - ''  -  ''
# ext.uls.interface - ext.uls.interfac  -  ext.uls.interface
# '' - ''  -  ''
# '' - ''  -  ''
# ext.cx.eventlogging.campaigns - ext.cx.eventlogging.campaign  -  ext.cx.eventlogging.campaigns
# '' - ''  -  ''
# '' - ''  -  ''
# ext.quicksurveys.init - ext.quicksurveys.init  -  ext.quicksurveys.init
# '' - ''  -  ''
# '' - ''  -  ''
# ext.centralNotice.geoIP - ext.centralnotice.geoip  -  ext.centralNotice.geoIP
# '' - ''  -  ''
# '' - ''  -  ''
# ext.centralNotice.startUp - ext.centralnotice.startup  -  ext.centralNotice.startUp
# '' - ''  -  ''
# RLQ=window.RLQ|| - rlq=window.rlq||  -  RLQ=window.RLQ||
# .push - .push  -  .push
# function - function  -  function
# { - {  -  {
# mw.loader.implement - mw.loader.impl  -  mw.loader.implement
# `` - ``  -  ``
# user.options - user.opt  -  user.options
# @ - @  -  @
# 1hzgi - 1hzgi  -  1hzgi
# '' - ''  -  ''
# function - function  -  function
# $ - $  -  $
# jQuery - jqueri  -  jQuery
# require - requir  -  require
# module - modul  -  module
# { - {  -  {
# /* - /*  -  /*
# @ - @  -  @
# nomin*/mw.user.tokens.set - nomin*/mw.user.tokens.set  -  nomin*/mw.user.tokens.set
# { - {  -  {
# `` - ``  -  ``
# patrolToken - patroltoken  -  patrolToken
# '' - ''  -  ''
# '' - ''  -  ''
# +\\ - +\\  -  +\\
# '' - ''  -  ''
# '' - ''  -  ''
# watchToken - watchtoken  -  watchToken
# '' - ''  -  ''
# '' - ''  -  ''
# +\\ - +\\  -  +\\
# '' - ''  -  ''
# '' - ''  -  ''
# csrfToken - csrftoken  -  csrfToken
# '' - ''  -  ''
# '' - ''  -  ''
# +\\ - +\\  -  +\\
# '' - ''  -  ''
# } - }  -  }
# } - }  -  }
# } - }  -  }
# Web - web  -  Web
# mining - mine  -  mining
# From - from  -  From
# Wikipedia - wikipedia  -  Wikipedia
# free - free  -  free
# encyclopedia - encyclopedia  -  encyclopedia
# Jump - jump  -  Jump
# navigation - navig  -  navigation
# Jump - jump  -  Jump
# search - search  -  search
# This - this  -  This
# article - articl  -  article
# may - may  -  may
# require - requir  -  require
# cleanup - cleanup  -  cleanup
# meet - meet  -  meet
# Wikipedia - wikipedia  -  Wikipedia
# quality - qualiti  -  quality
# standards - standard  -  standard
# No - no  -  No
# cleanup - cleanup  -  cleanup
# reason - reason  -  reason
# specified - specifi  -  specified
# Please - pleas  -  Please
# help - help  -  help
# improve - improv  -  improve
# article - articl  -  article
# June - june  -  June
# 2009 - 2009  -  2009
# Learn - learn  -  Learn
# remove - remov  -  remove
# template - templat  -  template
# message - messag  -  message
# Web - web  -  Web
# mining - mine  -  mining
# application - applic  -  application
# data - data  -  data
# mining - mine  -  mining
# techniques - techniqu  -  technique
# discover - discov  -  discover
# patterns - pattern  -  pattern
# World - world  -  World
# Wide - wide  -  Wide
# Web - web  -  Web
# As - as  -  As
# name - name  -  name
# proposes - propos  -  proposes
# information - inform  -  information
# gathered - gather  -  gathered
# mining - mine  -  mining
# web - web  -  web
# It - it  -  It
# makes - make  -  make
# utilization - util  -  utilization
# automated - autom  -  automated
# apparatuses - apparatus  -  apparatus
# reveal - reveal  -  reveal
# extricate - extric  -  extricate
# data - data  -  data
# servers - server  -  server
# web2 - web2  -  web2
# reports - report  -  report
# permits - permit  -  permit
# organizations - organ  -  organization
# get - get  -  get
# organized - organ  -  organized
# unstructured - unstructur  -  unstructured
# information - inform  -  information
# browser - browser  -  browser
# activities - activ  -  activity
# server - server  -  server
# logs - log  -  log
# website - websit  -  website
# link - link  -  link
# structure - structur  -  structure
# page - page  -  page
# content - content  -  content
# different - differ  -  different
# sources - sourc  -  source
# The - the  -  The
# goal - goal  -  goal
# Web - web  -  Web
# structure - structur  -  structure
# mining - mine  -  mining
# generate - generat  -  generate
# structural - structur  -  structural
# summary - summari  -  summary
# Web - web  -  Web
# site - site  -  site
# Web - web  -  Web
# page - page  -  page
# Technically - technic  -  Technically
# Web - web  -  Web
# content - content  -  content
# mining - mine  -  mining
# mainly - main  -  mainly
# focuses - focus  -  focus
# structure - structur  -  structure
# inner-document - inner-docu  -  inner-document
# Web - web  -  Web
# structure - structur  -  structure
# mining - mine  -  mining
# tries - tri  -  try
# discover - discov  -  discover
# link - link  -  link
# structure - structur  -  structure
# hyperlinks - hyperlink  -  hyperlink
# inter-document - inter-docu  -  inter-document
# level - level  -  level
# Based - base  -  Based
# topology - topolog  -  topology
# hyperlinks - hyperlink  -  hyperlink
# Web - web  -  Web
# structure - structur  -  structure
# mining - mine  -  mining
# categorize - categor  -  categorize
# Web - web  -  Web
# pages - page  -  page
# generate - generat  -  generate
# information - inform  -  information
# similarity - similar  -  similarity
# relationship - relationship  -  relationship
# different - differ  -  different
# Web - web  -  Web
# sites - site  -  site
# Web - web  -  Web
# structure - structur  -  structure
# mining - mine  -  mining
# also - also  -  also
# another - anoth  -  another
# direction - direct  -  direction
# – - –  -  –
# discovering - discov  -  discovering
# structure - structur  -  structure
# Web - web  -  Web
# document - document  -  document
# This - this  -  This
# type - type  -  type
# structure - structur  -  structure
# mining - mine  -  mining
# used - use  -  used
# reveal - reveal  -  reveal
# structure - structur  -  structure
# schema - schema  -  schema
# Web - web  -  Web
# pages - page  -  page
# would - would  -  would
# good - good  -  good
# navigation - navig  -  navigation
# purpose - purpos  -  purpose
# make - make  -  make
# possible - possibl  -  possible
# compare/integrate - compare/integr  -  compare/integrate
# Web - web  -  Web
# page - page  -  page
# schemes - scheme  -  scheme
# This - this  -  This
# type - type  -  type
# structure - structur  -  structure
# mining - mine  -  mining
# facilitate - facilit  -  facilitate
# introducing - introduc  -  introducing
# database - databas  -  database
# techniques - techniqu  -  technique
# accessing - access  -  accessing
# information - inform  -  information
# Web - web  -  Web
# pages - page  -  page
# providing - provid  -  providing
# reference - refer  -  reference
# schema - schema  -  schema
# Contents - content  -  Contents
# 1 - 1  -  1
# Web - web  -  Web
# mining - mine  -  mining
# types - type  -  type
# 2 - 2  -  2
# Web - web  -  Web
# usage - usag  -  usage
# mining - mine  -  mining
# 2.1 - 2.1  -  2.1
# Pros - pros  -  Pros
# 2.2 - 2.2  -  2.2
# Cons - con  -  Cons
# 3 - 3  -  3
# Web - web  -  Web
# structure - structur  -  structure
# mining - mine  -  mining
# 4 - 4  -  4
# Web - web  -  Web
# content - content  -  content
# mining - mine  -  mining
# 4.1 - 4.1  -  4.1
# Web - web  -  Web
# content - content  -  content
# mining - mine  -  mining
# foreign - foreign  -  foreign
# languages - languag  -  language
# 4.1.1 - 4.1.1  -  4.1.1
# Chinese - chines  -  Chinese
# 5 - 5  -  5
# See - see  -  See
# also - also  -  also
# 6 - 6  -  6
# References - refer  -  References
# 7 - 7  -  7
# Resources - resourc  -  Resources
# 7.1 - 7.1  -  7.1
# External - extern  -  External
# links - link  -  link
# 7.2 - 7.2  -  7.2
# Books - book  -  Books
# 7.3 - 7.3  -  7.3
# Bibliographic - bibliograph  -  Bibliographic
# references - refer  -  reference
# Web - web  -  Web
# mining - mine  -  mining
# types - type  -  type
# edit - edit  -  edit
# Web - web  -  Web
# mining - mine  -  mining
# divided - divid  -  divided
# three - three  -  three
# different - differ  -  different
# types - type  -  type
# – - –  -  –
# Web - web  -  Web
# usage - usag  -  usage
# mining - mine  -  mining
# Web - web  -  Web
# content - content  -  content
# mining - mine  -  mining
# Web - web  -  Web
# structure - structur  -  structure
# mining - mine  -  mining
# The - the  -  The
# general - general  -  general
# relationship - relationship  -  relationship
# categories - categori  -  category
# Web - web  -  Web
# mining - mine  -  mining
# objectives - object  -  objective
# data - data  -  data
# mining - mine  -  mining
# Comparison - comparison  -  Comparison
# Web - web  -  Web
# mining - mine  -  mining
# types - type  -  type
# 1 - 1  -  1
# Web - web  -  Web
# content - content  -  content
# mining - mine  -  mining
# Web - web  -  Web
# structure - structur  -  structure
# mining - mine  -  mining
# Web - web  -  Web
# usage - usag  -  usage
# mining - mine  -  mining
# IR - ir  -  IR
# view - view  -  view
# DB - db  -  DB
# view - view  -  view
# View - view  -  View
# data - data  -  data
# Unstructured - unstructur  -  Unstructured
# Structured - structur  -  Structured
# Semi-structured - semi-structur  -  Semi-structured
# Web - web  -  Web
# site - site  -  site
# DB - db  -  DB
# Link - link  -  Link
# structure - structur  -  structure
# Interactivity - interact  -  Interactivity
# Main - main  -  Main
# data - data  -  data
# Text - text  -  Text
# documents - document  -  document
# Hypertext - hypertext  -  Hypertext
# documents - document  -  document
# Hypertext - hypertext  -  Hypertext
# documents - document  -  document
# Link - link  -  Link
# structure - structur  -  structure
# Server - server  -  Server
# logs - log  -  log
# Browser - browser  -  Browser
# logs - log  -  log
# Representation - represent  -  Representation
# Bag - bag  -  Bag
# words - word  -  word
# n-gram - n-gram  -  n-gram
# terms - term  -  term
# phrases - phrase  -  phrase
# concepts - concept  -  concept
# ontology - ontolog  -  ontology
# Relational - relat  -  Relational
# Edge - edg  -  Edge
# labed - labe  -  labed
# graph - graph  -  graph
# Relational - relat  -  Relational
# Graph - graph  -  Graph
# Relational - relat  -  Relational
# table - tabl  -  table
# Graph - graph  -  Graph
# Method - method  -  Method
# Machine - machin  -  Machine
# learning - learn  -  learning
# Statistical - statist  -  Statistical
# including - includ  -  including
# NLP - nlp  -  NLP
# Proprietary - proprietari  -  Proprietary
# algorithms - algorithm  -  algorithm
# Association - associ  -  Association
# rules - rule  -  rule
# Proprietary - proprietari  -  Proprietary
# algorithms - algorithm  -  algorithm
# Machine - machin  -  Machine
# learning - learn  -  learning
# Statistical - statist  -  Statistical
# Association - associ  -  Association
# rules - rule  -  rule
# Application - applic  -  Application
# categories - categori  -  category
# Categorization - categor  -  Categorization
# Clustering - cluster  -  Clustering
# Finding - find  -  Finding
# extract - extract  -  extract
# rules - rule  -  rule
# Finding - find  -  Finding
# patterns - pattern  -  pattern
# text - text  -  text
# Finding - find  -  Finding
# frequent - frequent  -  frequent
# sub - sub  -  sub
# structures - structur  -  structure
# Web - web  -  Web
# site - site  -  site
# schema - schema  -  schema
# discovery - discoveri  -  discovery
# Categorization - categor  -  Categorization
# Clustering - cluster  -  Clustering
# Site - site  -  Site
# construction - construct  -  construction
# Adaptation - adapt  -  Adaptation
# management - manag  -  management
# Web - web  -  Web
# usage - usag  -  usage
# mining - mine  -  mining
# edit - edit  -  edit
# Web - web  -  Web
# usage - usag  -  usage
# mining - mine  -  mining
# application - applic  -  application
# data - data  -  data
# mining - mine  -  mining
# techniques - techniqu  -  technique
# discover - discov  -  discover
# interesting - interest  -  interesting
# usage - usag  -  usage
# patterns - pattern  -  pattern
# Web - web  -  Web
# data - data  -  data
# order - order  -  order
# understand - understand  -  understand
# better - better  -  better
# serve - serv  -  serve
# needs - need  -  need
# Web-based - web-bas  -  Web-based
# applications - applic  -  application
# Usage - usag  -  Usage
# data - data  -  data
# captures - captur  -  capture
# identity - ident  -  identity
# origin - origin  -  origin
# Web - web  -  Web
# users - user  -  user
# along - along  -  along
# browsing - brows  -  browsing
# behavior - behavior  -  behavior
# Web - web  -  Web
# site - site  -  site
# Web - web  -  Web
# usage - usag  -  usage
# mining - mine  -  mining
# classified - classifi  -  classified
# depending - depend  -  depending
# kind - kind  -  kind
# usage - usag  -  usage
# data - data  -  data
# considered - consid  -  considered
# Web - web  -  Web
# server - server  -  server
# data - data  -  data
# The - the  -  The
# user - user  -  user
# logs - log  -  log
# collected - collect  -  collected
# Web - web  -  Web
# server - server  -  server
# Typical - typic  -  Typical
# data - data  -  data
# includes - includ  -  includes
# IP - ip  -  IP
# address - address  -  address
# page - page  -  page
# reference - refer  -  reference
# access - access  -  access
# time - time  -  time
# Application - applic  -  Application
# server - server  -  server
# data - data  -  data
# Commercial - commerci  -  Commercial
# application - applic  -  application
# servers - server  -  server
# significant - signific  -  significant
# features - featur  -  feature
# enable - enabl  -  enable
# e-commerce - e-commerc  -  e-commerce
# applications - applic  -  application
# built - built  -  built
# top - top  -  top
# little - littl  -  little
# effort - effort  -  effort
# A - a  -  A
# key - key  -  key
# feature - featur  -  feature
# ability - abil  -  ability
# track - track  -  track
# various - various  -  various
# kinds - kind  -  kind
# business - busi  -  business
# events - event  -  event
# log - log  -  log
# application - applic  -  application
# server - server  -  server
# logs - log  -  log
# Application - applic  -  Application
# level - level  -  level
# data - data  -  data
# New - new  -  New
# kinds - kind  -  kind
# events - event  -  event
# defined - defin  -  defined
# application - applic  -  application
# logging - log  -  logging
# turned - turn  -  turned
# thus - thus  -  thus
# generating - generat  -  generating
# histories - histori  -  history
# specially - special  -  specially
# defined - defin  -  defined
# events - event  -  event
# Many - mani  -  Many
# end - end  -  end
# applications - applic  -  application
# require - requir  -  require
# combination - combin  -  combination
# one - one  -  one
# techniques - techniqu  -  technique
# applied - appli  -  applied
# categories - categori  -  category
# Studies - studi  -  Studies
# related - relat  -  related
# work - work  -  work
# 2 - 2  -  2
# concerned - concern  -  concerned
# two - two  -  two
# areas - area  -  area
# constraint-based - constraint-bas  -  constraint-based
# data - data  -  data
# mining - mine  -  mining
# algorithms - algorithm  -  algorithm
# applied - appli  -  applied
# Web - web  -  Web
# usage - usag  -  usage
# mining - mine  -  mining
# developed - develop  -  developed
# software - softwar  -  software
# tools - tool  -  tool
# systems - system  -  system
# Costa - costa  -  Costa
# Seco - seco  -  Seco
# demonstrated - demonstr  -  demonstrated
# web - web  -  web
# log - log  -  log
# mining - mine  -  mining
# used - use  -  used
# extract - extract  -  extract
# semantic - semant  -  semantic
# information - inform  -  information
# hyponymy - hyponymi  -  hyponymy
# relationships - relationship  -  relationship
# particular - particular  -  particular
# user - user  -  user
# given - given  -  given
# community - communiti  -  community
# Pros - pros  -  Pros
# edit - edit  -  edit
# Web - web  -  Web
# usage - usag  -  usage
# mining - mine  -  mining
# essentially - essenti  -  essentially
# many - mani  -  many
# advantages - advantag  -  advantage
# makes - make  -  make
# technology - technolog  -  technology
# attractive - attract  -  attractive
# corporations - corpor  -  corporation
# including - includ  -  including
# government - govern  -  government
# agencies - agenc  -  agency
# This - this  -  This
# technology - technolog  -  technology
# enabled - enabl  -  enabled
# e-commerce - e-commerc  -  e-commerce
# personalized - person  -  personalized
# marketing - market  -  marketing
# eventually - eventu  -  eventually
# results - result  -  result
# higher - higher  -  higher
# trade - trade  -  trade
# volumes - volum  -  volume
# Government - govern  -  Government
# agencies - agenc  -  agency
# using - use  -  using
# technology - technolog  -  technology
# classify - classifi  -  classify
# threats - threat  -  threat
# fight - fight  -  fight
# terrorism - terror  -  terrorism
# The - the  -  The
# predicting - predict  -  predicting
# capability - capabl  -  capability
# mining - mine  -  mining
# applications - applic  -  application
# benefit - benefit  -  benefit
# society - societi  -  society
# identifying - identifi  -  identifying
# criminal - crimin  -  criminal
# activities - activ  -  activity
# Companies - compani  -  Companies
# establish - establish  -  establish
# better - better  -  better
# customer - custom  -  customer
# relationship - relationship  -  relationship
# understanding - understand  -  understanding
# needs - need  -  need
# customer - custom  -  customer
# better - better  -  better
# reacting - react  -  reacting
# customer - custom  -  customer
# needs - need  -  need
# faster - faster  -  faster
# Companies - compani  -  Companies
# find - find  -  find
# attract - attract  -  attract
# retain - retain  -  retain
# customers - custom  -  customer
# save - save  -  save
# production - product  -  production
# costs - cost  -  cost
# utilizing - util  -  utilizing
# acquired - acquir  -  acquired
# insight - insight  -  insight
# customer - custom  -  customer
# requirements - requir  -  requirement
# They - they  -  They
# increase - increas  -  increase
# profitability - profit  -  profitability
# target - target  -  target
# pricing - price  -  pricing
# based - base  -  based
# profiles - profil  -  profile
# created - creat  -  created
# They - they  -  They
# even - even  -  even
# find - find  -  find
# customers - custom  -  customer
# might - might  -  might
# default - default  -  default
# competitor - competitor  -  competitor
# company - compani  -  company
# try - tri  -  try
# retain - retain  -  retain
# customer - custom  -  customer
# providing - provid  -  providing
# promotional - promot  -  promotional
# offers - offer  -  offer
# specific - specif  -  specific
# customer - custom  -  customer
# thus - thus  -  thus
# reducing - reduc  -  reducing
# risk - risk  -  risk
# losing - lose  -  losing
# customer - custom  -  customer
# customers - custom  -  customer
# More - more  -  More
# benefits - benefit  -  benefit
# web - web  -  web
# usage - usag  -  usage
# mining - mine  -  mining
# particularly - particular  -  particularly
# area - area  -  area
# personalization - person  -  personalization
# outlined - outlin  -  outlined
# specific - specif  -  specific
# frameworks - framework  -  framework
# probabilistic - probabilist  -  probabilistic
# latent - latent  -  latent
# semantic - semant  -  semantic
# analysis - analysi  -  analysis
# model - model  -  model
# offer - offer  -  offer
# additional - addit  -  additional
# features - featur  -  feature
# user - user  -  user
# behavior - behavior  -  behavior
# access - access  -  access
# pattern - pattern  -  pattern
# 3 - 3  -  3
# This - this  -  This
# process - process  -  process
# provides - provid  -  provides
# user - user  -  user
# relevant - relev  -  relevant
# content - content  -  content
# collaborative - collabor  -  collaborative
# recommendation - recommend  -  recommendation
# These - these  -  These
# models - model  -  model
# also - also  -  also
# demonstrate - demonstr  -  demonstrate
# capability - capabl  -  capability
# web - web  -  web
# usage - usag  -  usage
# mining - mine  -  mining
# technology - technolog  -  technology
# address - address  -  address
# problems - problem  -  problem
# associated - associ  -  associated
# traditional - tradit  -  traditional
# techniques - techniqu  -  technique
# biases - bias  -  bias
# questions - question  -  question
# regarding - regard  -  regarding
# validity - valid  -  validity
# since - sinc  -  since
# data - data  -  data
# patterns - pattern  -  pattern
# obtained - obtain  -  obtained
# subjective - subject  -  subjective
# degrade - degrad  -  degrade
# time - time  -  time
# 4 - 4  -  4
# There - there  -  There
# also - also  -  also
# elements - element  -  element
# unique - uniqu  -  unique
# web - web  -  web
# usage - usag  -  usage
# mining - mine  -  mining
# show - show  -  show
# technology - technolog  -  technology
# benefits - benefit  -  benefit
# include - includ  -  include
# way - way  -  way
# semantic - semant  -  semantic
# knowledge - knowledg  -  knowledge
# applied - appli  -  applied
# interpreting - interpret  -  interpreting
# analyzing - analyz  -  analyzing
# reasoning - reason  -  reasoning
# usage - usag  -  usage
# patterns - pattern  -  pattern
# mining - mine  -  mining
# phase - phase  -  phase
# 5 - 5  -  5
# Cons - con  -  Cons
# edit - edit  -  edit
# Web - web  -  Web
# usage - usag  -  usage
# mining - mine  -  mining
# create - creat  -  create
# issues - issu  -  issue
# technology - technolog  -  technology
# used - use  -  used
# data - data  -  data
# personal - person  -  personal
# nature - natur  -  nature
# might - might  -  might
# cause - caus  -  cause
# concerns - concern  -  concern
# The - the  -  The
# criticized - critic  -  criticized
# ethical - ethic  -  ethical
# issue - issu  -  issue
# involving - involv  -  involving
# web - web  -  web
# usage - usag  -  usage
# mining - mine  -  mining
# invasion - invas  -  invasion
# privacy - privaci  -  privacy
# Privacy - privaci  -  Privacy
# considered - consid  -  considered
# lost - lost  -  lost
# information - inform  -  information
# concerning - concern  -  concerning
# individual - individu  -  individual
# obtained - obtain  -  obtained
# used - use  -  used
# disseminated - dissemin  -  disseminated
# especially - especi  -  especially
# occurs - occur  -  occurs
# without - without  -  without
# individual - individu  -  individual
# knowledge - knowledg  -  knowledge
# consent - consent  -  consent
# 6 - 6  -  6
# The - the  -  The
# obtained - obtain  -  obtained
# data - data  -  data
# analyzed - analyz  -  analyzed
# made - made  -  made
# anonymous - anonym  -  anonymous
# clustered - cluster  -  clustered
# form - form  -  form
# anonymous - anonym  -  anonymous
# profiles - profil  -  profile
# 6 - 6  -  6
# These - these  -  These
# applications - applic  -  application
# de-individualize - de-individu  -  de-individualize
# users - user  -  user
# judging - judg  -  judging
# mouse - mous  -  mouse
# clicks - click  -  click
# rather - rather  -  rather
# identifying - identifi  -  identifying
# information - inform  -  information
# De-individualization - de-individu  -  De-individualization
# general - general  -  general
# defined - defin  -  defined
# tendency - tendenc  -  tendency
# judging - judg  -  judging
# treating - treat  -  treating
# people - peopl  -  people
# basis - basi  -  basis
# group - group  -  group
# characteristics - characterist  -  characteristic
# instead - instead  -  instead
# individual - individu  -  individual
# characteristics - characterist  -  characteristic
# merits - merit  -  merit
# 6 - 6  -  6
# Another - anoth  -  Another
# important - import  -  important
# concern - concern  -  concern
# companies - compani  -  company
# collecting - collect  -  collecting
# data - data  -  data
# specific - specif  -  specific
# purpose - purpos  -  purpose
# might - might  -  might
# use - use  -  use
# data - data  -  data
# totally - total  -  totally
# different - differ  -  different
# purposes - purpos  -  purpose
# essentially - essenti  -  essentially
# violates - violat  -  violates
# user - user  -  user
# interests - interest  -  interest
# The - the  -  The
# growing - grow  -  growing
# trend - trend  -  trend
# selling - sell  -  selling
# personal - person  -  personal
# data - data  -  data
# commodity - commod  -  commodity
# encourages - encourag  -  encourages
# website - websit  -  website
# owners - owner  -  owner
# trade - trade  -  trade
# personal - person  -  personal
# data - data  -  data
# obtained - obtain  -  obtained
# site - site  -  site
# This - this  -  This
# trend - trend  -  trend
# increased - increas  -  increased
# amount - amount  -  amount
# data - data  -  data
# captured - captur  -  captured
# traded - trade  -  traded
# increasing - increas  -  increasing
# likeliness - likeli  -  likeliness
# one - one  -  one
# privacy - privaci  -  privacy
# invaded - invad  -  invaded
# The - the  -  The
# companies - compani  -  company
# buy - buy  -  buy
# data - data  -  data
# obliged - oblig  -  obliged
# make - make  -  make
# anonymous - anonym  -  anonymous
# companies - compani  -  company
# considered - consid  -  considered
# authors - author  -  author
# specific - specif  -  specific
# release - releas  -  release
# mining - mine  -  mining
# patterns - pattern  -  pattern
# They - they  -  They
# legally - legal  -  legally
# responsible - respons  -  responsible
# contents - content  -  content
# release - releas  -  release
# inaccuracies - inaccuraci  -  inaccuracy
# release - releas  -  release
# result - result  -  result
# serious - serious  -  serious
# lawsuits - lawsuit  -  lawsuit
# law - law  -  law
# preventing - prevent  -  preventing
# trading - trade  -  trading
# data - data  -  data
# Some - some  -  Some
# mining - mine  -  mining
# algorithms - algorithm  -  algorithm
# might - might  -  might
# use - use  -  use
# controversial - controversi  -  controversial
# attributes - attribut  -  attribute
# like - like  -  like
# sex - sex  -  sex
# race - race  -  race
# religion - religion  -  religion
# sexual - sexual  -  sexual
# orientation - orient  -  orientation
# categorize - categor  -  categorize
# individuals - individu  -  individual
# These - these  -  These
# practices - practic  -  practice
# might - might  -  might
# anti-discrimination - anti-discrimin  -  anti-discrimination
# legislation - legisl  -  legislation
# 7 - 7  -  7
# The - the  -  The
# applications - applic  -  application
# make - make  -  make
# hard - hard  -  hard
# identify - identifi  -  identify
# use - use  -  use
# controversial - controversi  -  controversial
# attributes - attribut  -  attribute
# strong - strong  -  strong
# rule - rule  -  rule
# usage - usag  -  usage
# algorithms - algorithm  -  algorithm
# attributes - attribut  -  attribute
# This - this  -  This
# process - process  -  process
# could - could  -  could
# result - result  -  result
# denial - denial  -  denial
# service - servic  -  service
# privilege - privileg  -  privilege
# individual - individu  -  individual
# based - base  -  based
# race - race  -  race
# religion - religion  -  religion
# sexual - sexual  -  sexual
# orientation - orient  -  orientation
# This - this  -  This
# situation - situat  -  situation
# avoided - avoid  -  avoided
# high - high  -  high
# ethical - ethic  -  ethical
# standards - standard  -  standard
# maintained - maintain  -  maintained
# data - data  -  data
# mining - mine  -  mining
# company - compani  -  company
# The - the  -  The
# collected - collect  -  collected
# data - data  -  data
# made - made  -  made
# anonymous - anonym  -  anonymous
# obtained - obtain  -  obtained
# data - data  -  data
# obtained - obtain  -  obtained
# patterns - pattern  -  pattern
# traced - trace  -  traced
# back - back  -  back
# individual - individu  -  individual
# It - it  -  It
# might - might  -  might
# look - look  -  look
# poses - pose  -  pose
# threat - threat  -  threat
# one - one  -  one
# privacy - privaci  -  privacy
# however - howev  -  however
# additional - addit  -  additional
# information - inform  -  information
# inferred - infer  -  inferred
# application - applic  -  application
# combining - combin  -  combining
# two - two  -  two
# separate - separ  -  separate
# unscrupulous - unscrupul  -  unscrupulous
# data - data  -  data
# user - user  -  user
# Web - web  -  Web
# structure - structur  -  structure
# mining - mine  -  mining
# edit - edit  -  edit
# This - this  -  This
# section - section  -  section
# needs - need  -  need
# expansion - expans  -  expansion
# You - you  -  You
# help - help  -  help
# adding - ad  -  adding
# June - june  -  June
# 2015 - 2015  -  2015
# Web - web  -  Web
# structure - structur  -  structure
# mining - mine  -  mining
# uses - use  -  us
# graph - graph  -  graph
# theory - theori  -  theory
# analyze - analyz  -  analyze
# node - node  -  node
# connection - connect  -  connection
# structure - structur  -  structure
# web - web  -  web
# site - site  -  site
# According - accord  -  According
# type - type  -  type
# web - web  -  web
# structural - structur  -  structural
# data - data  -  data
# web - web  -  web
# structure - structur  -  structure
# mining - mine  -  mining
# divided - divid  -  divided
# two - two  -  two
# kinds - kind  -  kind
# Extracting - extract  -  Extracting
# patterns - pattern  -  pattern
# hyperlinks - hyperlink  -  hyperlink
# web - web  -  web
# hyperlink - hyperlink  -  hyperlink
# structural - structur  -  structural
# component - compon  -  component
# connects - connect  -  connects
# web - web  -  web
# page - page  -  page
# different - differ  -  different
# location - locat  -  location
# Mining - mine  -  Mining
# document - document  -  document
# structure - structur  -  structure
# analysis - analysi  -  analysis
# tree-like - tree-lik  -  tree-like
# structure - structur  -  structure
# page - page  -  page
# structures - structur  -  structure
# describe - describ  -  describe
# HTML - html  -  HTML
# XML - xml  -  XML
# tag - tag  -  tag
# usage - usag  -  usage
# Web - web  -  Web
# structure - structur  -  structure
# mining - mine  -  mining
# terminology - terminolog  -  terminology
# Web - web  -  Web
# graph - graph  -  graph
# directed - direct  -  directed
# graph - graph  -  graph
# representing - repres  -  representing
# web - web  -  web
# Node - node  -  Node
# web - web  -  web
# page - page  -  page
# graph - graph  -  graph
# Edge - edg  -  Edge
# hyperlinks - hyperlink  -  hyperlink
# In - in  -  In
# degree - degre  -  degree
# number - number  -  number
# links - link  -  link
# pointing - point  -  pointing
# particular - particular  -  particular
# node - node  -  node
# Out - out  -  Out
# degree - degre  -  degree
# number - number  -  number
# links - link  -  link
# generated - generat  -  generated
# particular - particular  -  particular
# node - node  -  node
# Techniques - techniqu  -  Techniques
# web - web  -  web
# structure - structur  -  structure
# mining - mine  -  mining
# PageRank - pagerank  -  PageRank
# algorithm - algorithm  -  algorithm
# used - use  -  used
# Google - googl  -  Google
# rank - rank  -  rank
# search - search  -  search
# results - result  -  result
# The - the  -  The
# name - name  -  name
# algorithm - algorithm  -  algorithm
# given - given  -  given
# Google-founder - google-found  -  Google-founder
# Larry - larri  -  Larry
# Page - page  -  Page
# The - the  -  The
# rank - rank  -  rank
# page - page  -  page
# decided - decid  -  decided
# number - number  -  number
# links - link  -  link
# pointing - point  -  pointing
# target - target  -  target
# node - node  -  node
# Web - web  -  Web
# content - content  -  content
# mining - mine  -  mining
# edit - edit  -  edit
# Web - web  -  Web
# content - content  -  content
# mining - mine  -  mining
# mining - mine  -  mining
# extraction - extract  -  extraction
# integration - integr  -  integration
# useful - use  -  useful
# data - data  -  data
# information - inform  -  information
# knowledge - knowledg  -  knowledge
# Web - web  -  Web
# page - page  -  page
# content - content  -  content
# The - the  -  The
# heterogeneity - heterogen  -  heterogeneity
# lack - lack  -  lack
# structure - structur  -  structure
# permits - permit  -  permit
# much - much  -  much
# ever-expanding - ever-expand  -  ever-expanding
# information - inform  -  information
# sources - sourc  -  source
# World - world  -  World
# Wide - wide  -  Wide
# Web - web  -  Web
# hypertext - hypertext  -  hypertext
# documents - document  -  document
# makes - make  -  make
# automated - autom  -  automated
# discovery - discoveri  -  discovery
# organization - organ  -  organization
# search - search  -  search
# indexing - index  -  indexing
# tools - tool  -  tool
# Internet - internet  -  Internet
# World - world  -  World
# Wide - wide  -  Wide
# Web - web  -  Web
# Lycos - lyco  -  Lycos
# Alta - alta  -  Alta
# Vista - vista  -  Vista
# WebCrawler - webcrawl  -  WebCrawler
# Aliweb - aliweb  -  Aliweb
# MetaCrawler - metacrawl  -  MetaCrawler
# others - other  -  others
# provide - provid  -  provide
# comfort - comfort  -  comfort
# users - user  -  user
# generally - general  -  generally
# provide - provid  -  provide
# structural - structur  -  structural
# information - inform  -  information
# categorize - categor  -  categorize
# filter - filter  -  filter
# interpret - interpret  -  interpret
# documents - document  -  document
# These - these  -  These
# factors - factor  -  factor
# prompted - prompt  -  prompted
# researchers - research  -  researcher
# develop - develop  -  develop
# intelligent - intellig  -  intelligent
# tools - tool  -  tool
# information - inform  -  information
# retrieval - retriev  -  retrieval
# intelligent - intellig  -  intelligent
# web - web  -  web
# agents - agent  -  agent
# well - well  -  well
# extend - extend  -  extend
# database - databas  -  database
# data - data  -  data
# mining - mine  -  mining
# techniques - techniqu  -  technique
# provide - provid  -  provide
# higher - higher  -  higher
# level - level  -  level
# organization - organ  -  organization
# semi-structured - semi-structur  -  semi-structured
# data - data  -  data
# available - avail  -  available
# web - web  -  web
# The - the  -  The
# agent-based - agent-bas  -  agent-based
# approach - approach  -  approach
# web - web  -  web
# mining - mine  -  mining
# involves - involv  -  involves
# development - develop  -  development
# sophisticated - sophist  -  sophisticated
# AI - ai  -  AI
# systems - system  -  system
# act - act  -  act
# autonomously - autonom  -  autonomously
# semi-autonomously - semi-autonom  -  semi-autonomously
# behalf - behalf  -  behalf
# particular - particular  -  particular
# user - user  -  user
# discover - discov  -  discover
# organize - organ  -  organize
# web-based - web-bas  -  web-based
# information - inform  -  information
# Web - web  -  Web
# content - content  -  content
# mining - mine  -  mining
# differentiated - differenti  -  differentiated
# two - two  -  two
# different - differ  -  different
# points - point  -  point
# view - view  -  view
# 8 - 8  -  8
# Information - inform  -  Information
# Retrieval - retriev  -  Retrieval
# View - view  -  View
# Database - databas  -  Database
# View - view  -  View
# 9 - 9  -  9
# summarized - summar  -  summarized
# research - research  -  research
# works - work  -  work
# done - done  -  done
# unstructured - unstructur  -  unstructured
# data - data  -  data
# semi-structured - semi-structur  -  semi-structured
# data - data  -  data
# information - inform  -  information
# retrieval - retriev  -  retrieval
# view - view  -  view
# It - it  -  It
# shows - show  -  show
# researches - research  -  research
# use - use  -  use
# bag - bag  -  bag
# words - word  -  word
# based - base  -  based
# statistics - statist  -  statistic
# single - singl  -  single
# words - word  -  word
# isolation - isol  -  isolation
# represent - repres  -  represent
# unstructured - unstructur  -  unstructured
# text - text  -  text
# take - take  -  take
# single - singl  -  single
# word - word  -  word
# found - found  -  found
# training - train  -  training
# corpus - corpus  -  corpus
# features - featur  -  feature
# For - for  -  For
# semi-structured - semi-structur  -  semi-structured
# data - data  -  data
# works - work  -  work
# utilize - util  -  utilize
# HTML - html  -  HTML
# structures - structur  -  structure
# inside - insid  -  inside
# documents - document  -  document
# utilized - util  -  utilized
# ...
# personalization - person  -  personalization
# survey - survey  -  survey
# ” - ”  -  ”
# User - user  -  User
# modelling - model  -  modelling
# user - user  -  user
# adapted - adapt  -  adapted
# interaction - interact  -  interaction
# journal - journal  -  journal
# Vol.13 - vol.13  -  Vol.13
# Issue - issu  -  Issue
# 4 - 4  -  4
# pp - pp  -  pp
# 311–372 - 311–372  -  311–372
# I-Hsien - i-hsien  -  I-Hsien
# Ting - ting  -  Ting
# Chris - chris  -  Chris
# Kimble - kimbl  -  Kimble
# Daniel - daniel  -  Daniel
# Kudenko - kudenko  -  Kudenko
# 2005 - 2005  -  2005
# `` - ``  -  ``
# A - a  -  A
# Pattern - pattern  -  Pattern
# Restore - restor  -  Restore
# Method - method  -  Method
# Restoring - restor  -  Restoring
# Missing - miss  -  Missing
# Patterns - pattern  -  Patterns
# Server - server  -  Server
# Side - side  -  Side
# Clickstream - clickstream  -  Clickstream
# Data - data  -  Data
# '' - ''  -  ''
# I-Hsien - i-hsien  -  I-Hsien
# Ting - ting  -  Ting
# Chris - chris  -  Chris
# Kimble - kimbl  -  Kimble
# Daniel - daniel  -  Daniel
# Kudenko - kudenko  -  Kudenko
# 2006 - 2006  -  2006
# `` - ``  -  ``
# UBB - ubb  -  UBB
# Mining - mine  -  Mining
# Finding - find  -  Finding
# Unexpected - unexpect  -  Unexpected
# Browsing - brows  -  Browsing
# Behaviour - behaviour  -  Behaviour
# Clickstream - clickstream  -  Clickstream
# Data - data  -  Data
# improve - improv  -  improve
# Web - web  -  Web
# Site - site  -  Site
# ’ - ’  -  ’
# Design - design  -  Design
# '' - ''  -  ''
# Weichbroth - weichbroth  -  Weichbroth
# P. - p.  -  P.
# Owoc - owoc  -  Owoc
# M. - m.  -  M.
# Pleszkun - pleszkun  -  Pleszkun
# M. - m.  -  M.
# 2012 - 2012  -  2012
# `` - ``  -  ``
# Web - web  -  Web
# User - user  -  User
# Navigation - navig  -  Navigation
# Patterns - pattern  -  Patterns
# Discovery - discoveri  -  Discovery
# WWW - www  -  WWW
# Server - server  -  Server
# Log - log  -  Log
# Files - file  -  Files
# '' - ''  -  ''
# Retrieved - retriev  -  Retrieved
# `` - ``  -  ``
# https - https  -  http
# //en.wikipedia.org/w/index.php - //en.wikipedia.org/w/index.php  -  //en.wikipedia.org/w/index.php
# title=Web_mining - title=web_min  -  title=Web_mining
# oldid=965466027 - oldid=965466027  -  oldid=965466027
# '' - ''  -  ''
# Categories - categori  -  Categories
# Web - web  -  Web
# analyticsData - analyticsdata  -  analyticsData
# miningWorld - miningworld  -  miningWorld
# Wide - wide  -  Wide
# WebHidden - webhidden  -  WebHidden
# categories - categori  -  category
# CS1 - cs1  -  CS1
# errors - error  -  error
# missing - miss  -  missing
# periodicalArticles - periodicalarticl  -  periodicalArticles
# needing - need  -  needing
# cleanup - cleanup  -  cleanup
# June - june  -  June
# 2009All - 2009all  -  2009All
# pages - page  -  page
# needing - need  -  needing
# cleanupCleanup - cleanupcleanup  -  cleanupCleanup
# tagged - tag  -  tagged
# articles - articl  -  article
# without - without  -  without
# reason - reason  -  reason
# field - field  -  field
# June - june  -  June
# 2009Wikipedia - 2009wikipedia  -  2009Wikipedia
# pages - page  -  page
# needing - need  -  needing
# cleanup - cleanup  -  cleanup
# June - june  -  June
# 2009Articles - 2009articl  -  2009Articles
# expanded - expand  -  expanded
# June - june  -  June
# 2015All - 2015all  -  2015All
# articles - articl  -  article
# expandedArticles - expandedarticl  -  expandedArticles
# using - use  -  using
# small - small  -  small
# message - messag  -  message
# boxesArticles - boxesarticl  -  boxesArticles
# lacking - lack  -  lacking
# in-text - in-text  -  in-text
# citations - citat  -  citation
# September - septemb  -  September
# 2009All - 2009all  -  2009All
# articles - articl  -  article
# lacking - lack  -  lacking
# in-text - in-text  -  in-text
# citations - citat  -  citation
# Navigation - navig  -  Navigation
# menu - menu  -  menu
# Personal - person  -  Personal
# tools - tool  -  tool
# Not - not  -  Not
# logged - log  -  logged
# inTalkContributionsCreate - intalkcontributionscr  -  inTalkContributionsCreate
# accountLog - accountlog  -  accountLog
# Namespaces - namespac  -  Namespaces
# ArticleTalk - articletalk  -  ArticleTalk
# Variants - variant  -  Variants
# Views - view  -  Views
# ReadEditView - readeditview  -  ReadEditView
# history - histori  -  history
# More - more  -  More
# Search - search  -  Search
# Navigation - navig  -  Navigation
# Main - main  -  Main
# pageContentsCurrent - pagecontentscurr  -  pageContentsCurrent
# eventsRandom - eventsrandom  -  eventsRandom
# articleAbout - articleabout  -  articleAbout
# WikipediaContact - wikipediacontact  -  WikipediaContact
# usDonateWikipedia - usdonatewikipedia  -  usDonateWikipedia
# store - store  -  store
# Contribute - contribut  -  Contribute
# HelpCommunity - helpcommun  -  HelpCommunity
# portalRecent - portalrec  -  portalRecent
# changesUpload - changesupload  -  changesUpload
# file - file  -  file
# Tools - tool  -  Tools
# What - what  -  What
# links - link  -  link
# hereRelated - hererel  -  hereRelated
# changesUpload - changesupload  -  changesUpload
# fileSpecial - filespeci  -  fileSpecial
# pagesPermanent - pagesperman  -  pagesPermanent
# linkPage - linkpag  -  linkPage
# informationCite - informationcit  -  informationCite
# pageWikidata - pagewikidata  -  pageWikidata
# item - item  -  item
# Print/export - print/export  -  Print/export
# Download - download  -  Download
# PDFPrintable - pdfprintabl  -  PDFPrintable
# version - version  -  version
# Languages - languag  -  Languages
# العربيةDeutschEspañolEuskaraفارسیFrançais한국어हिन्दीHrvatskiMagyar日本語PortuguêsРусскийSlovenčinaไทย - العربيةdeutschespañoleuskaraفارسیfrançais한국어हिन्दीhrvatskimagyar日本語portuguêsрусскийslovenčinaไทย  -  العربيةDeutschEspañolEuskaraفارسیFrançais한국어हिन्दीHrvatskiMagyar日本語PortuguêsРусскийSlovenčinaไทย
# Edit - edit  -  Edit
# links - link  -  link
# This - this  -  This
# page - page  -  page
# last - last  -  last
# edited - edit  -  edited
# 1 - 1  -  1
# July - juli  -  July
# 2020 - 2020  -  2020
# 13:43 - 13:43  -  13:43
# UTC - utc  -  UTC
# Text - text  -  Text
# available - avail  -  available
# Creative - creativ  -  Creative
# Commons - common  -  Commons
# Attribution-ShareAlike - attribution-sharealik  -  Attribution-ShareAlike
# License - licens  -  License
# additional - addit  -  additional
# terms - term  -  term
# may - may  -  may
# apply - appli  -  apply
# By - by  -  By
# using - use  -  using
# site - site  -  site
# agree - agre  -  agree
# Terms - term  -  Terms
# Use - use  -  Use
# Privacy - privaci  -  Privacy
# Policy - polici  -  Policy
# Wikipedia® - wikipedia®  -  Wikipedia®
# registered - regist  -  registered
# trademark - trademark  -  trademark
# Wikimedia - wikimedia  -  Wikimedia
# Foundation - foundat  -  Foundation
# Inc. - inc.  -  Inc.
# non-profit - non-profit  -  non-profit
# organization - organ  -  organization
# Privacy - privaci  -  Privacy
# policy - polici  -  policy
# About - about  -  About
# Wikipedia - wikipedia  -  Wikipedia
# Disclaimers - disclaim  -  Disclaimers
# Contact - contact  -  Contact
# Wikipedia - wikipedia  -  Wikipedia
# Developers - develop  -  Developers
# Statistics - statist  -  Statistics
# Cookie - cooki  -  Cookie
# statement - statement  -  statement
# Mobile - mobil  -  Mobile
# view - view  -  view
# RLQ=window.RLQ|| - rlq=window.rlq||  -  RLQ=window.RLQ||
# .push - .push  -  .push
# function - function  -  function
# { - {  -  {
# mw.config.set - mw.config.set  -  mw.config.set
# { - {  -  {
# `` - ``  -  ``
# wgPageParseReport - wgpageparsereport  -  wgPageParseReport
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# limitreport - limitreport  -  limitreport
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# cputime - cputim  -  cputime
# '' - ''  -  ''
# '' - ''  -  ''
# 0.300 - 0.300  -  0.300
# '' - ''  -  ''
# '' - ''  -  ''
# walltime - walltim  -  walltime
# '' - ''  -  ''
# '' - ''  -  ''
# 0.409 - 0.409  -  0.409
# '' - ''  -  ''
# '' - ''  -  ''
# ppvisitednodes - ppvisitednod  -  ppvisitednodes
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# value - valu  -  value
# '' - ''  -  ''
# :1424 - :1424  -  :1424
# '' - ''  -  ''
# limit - limit  -  limit
# '' - ''  -  ''
# :1000000 - :1000000  -  :1000000
# } - }  -  }
# '' - ''  -  ''
# postexpandincludesize - postexpandincludes  -  postexpandincludesize
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# value - valu  -  value
# '' - ''  -  ''
# :36057 - :36057  -  :36057
# '' - ''  -  ''
# limit - limit  -  limit
# '' - ''  -  ''
# :2097152 - :2097152  -  :2097152
# } - }  -  }
# '' - ''  -  ''
# templateargumentsize - templatearguments  -  templateargumentsize
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# value - valu  -  value
# '' - ''  -  ''
# :3521 - :3521  -  :3521
# '' - ''  -  ''
# limit - limit  -  limit
# '' - ''  -  ''
# :2097152 - :2097152  -  :2097152
# } - }  -  }
# '' - ''  -  ''
# expansiondepth - expansiondepth  -  expansiondepth
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# value - valu  -  value
# '' - ''  -  ''
# :16 - :16  -  :16
# '' - ''  -  ''
# limit - limit  -  limit
# '' - ''  -  ''
# :40 - :40  -  :40
# } - }  -  }
# '' - ''  -  ''
# expensivefunctioncount - expensivefunctioncount  -  expensivefunctioncount
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# value - valu  -  value
# '' - ''  -  ''
# :6 - :6  -  :6
# '' - ''  -  ''
# limit - limit  -  limit
# '' - ''  -  ''
# :500 - :500  -  :500
# } - }  -  }
# '' - ''  -  ''
# unstrip-depth - unstrip-depth  -  unstrip-depth
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# value - valu  -  value
# '' - ''  -  ''
# :1 - :1  -  :1
# '' - ''  -  ''
# limit - limit  -  limit
# '' - ''  -  ''
# :20 - :20  -  :20
# } - }  -  }
# '' - ''  -  ''
# unstrip-size - unstrip-s  -  unstrip-size
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# value - valu  -  value
# '' - ''  -  ''
# :39313 - :39313  -  :39313
# '' - ''  -  ''
# limit - limit  -  limit
# '' - ''  -  ''
# :5000000 - :5000000  -  :5000000
# } - }  -  }
# '' - ''  -  ''
# entityaccesscount - entityaccesscount  -  entityaccesscount
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# value - valu  -  value
# '' - ''  -  ''
# :0 - :0  -  :0
# '' - ''  -  ''
# limit - limit  -  limit
# '' - ''  -  ''
# :400 - :400  -  :400
# } - }  -  }
# '' - ''  -  ''
# timingprofile - timingprofil  -  timingprofile
# '' - ''  -  ''
# `` - ``  -  ``
# 100.00 - 100.00  -  100.00
# % - %  -  %
# 326.954 - 326.954  -  326.954
# 1 - 1  -  1
# -total - -total  -  -total
# '' - ''  -  ''
# '' - ''  -  ''
# 50.46 - 50.46  -  50.46
# % - %  -  %
# 164.992 - 164.992  -  164.992
# 1 - 1  -  1
# Template - templat  -  Template
# Reflist - reflist  -  Reflist
# '' - ''  -  ''
# '' - ''  -  ''
# 32.85 - 32.85  -  32.85
# % - %  -  %
# 107.398 - 107.398  -  107.398
# 1 - 1  -  1
# Template - templat  -  Template
# Cleanup - cleanup  -  Cleanup
# '' - ''  -  ''
# '' - ''  -  ''
# 31.35 - 31.35  -  31.35
# % - %  -  %
# 102.486 - 102.486  -  102.486
# 3 - 3  -  3
# Template - templat  -  Template
# Cite_book - cite_book  -  Cite_book
# '' - ''  -  ''
# '' - ''  -  ''
# 19.77 - 19.77  -  19.77
# % - %  -  %
# 64.635 - 64.635  -  64.635
# 3 - 3  -  3
# Template - templat  -  Template
# Ambox - ambox  -  Ambox
# '' - ''  -  ''
# '' - ''  -  ''
# 17.08 - 17.08  -  17.08
# % - %  -  %
# 55.853 - 55.853  -  55.853
# 3 - 3  -  3
# Template - templat  -  Template
# Main_other - main_oth  -  Main_other
# '' - ''  -  ''
# '' - ''  -  ''
# 9.72 - 9.72  -  9.72
# % - %  -  %
# 31.794 - 31.794  -  31.794
# 1 - 1  -  1
# Template - templat  -  Template
# Category_handler - category_handl  -  Category_handler
# '' - ''  -  ''
# '' - ''  -  ''
# 7.67 - 7.67  -  7.67
# % - %  -  %
# 25.065 - 25.065  -  25.065
# 5 - 5  -  5
# Template - templat  -  Template
# Cite_journal - cite_journ  -  Cite_journal
# '' - ''  -  ''
# '' - ''  -  ''
# 6.06 - 6.06  -  6.06
# % - %  -  %
# 19.827 - 19.827  -  19.827
# 1 - 1  -  1
# Template - templat  -  Template
# More_footnotes - more_footnot  -  More_footnotes
# '' - ''  -  ''
# '' - ''  -  ''
# 5.94 - 5.94  -  5.94
# % - %  -  %
# 19.420 - 19.420  -  19.420
# 1 - 1  -  1
# Template - templat  -  Template
# DMC - dmc  -  DMC
# '' - ''  -  ''
# } - }  -  }
# '' - ''  -  ''
# scribunto - scribunto  -  scribunto
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# limitreport-timeusage - limitreport-timeusag  -  limitreport-timeusage
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# value - valu  -  value
# '' - ''  -  ''
# '' - ''  -  ''
# 0.134 - 0.134  -  0.134
# '' - ''  -  ''
# '' - ''  -  ''
# limit - limit  -  limit
# '' - ''  -  ''
# '' - ''  -  ''
# 10.000 - 10.000  -  10.000
# '' - ''  -  ''
# } - }  -  }
# '' - ''  -  ''
# limitreport-memusage - limitreport-memusag  -  limitreport-memusage
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# value - valu  -  value
# '' - ''  -  ''
# :4498450 - :4498450  -  :4498450
# '' - ''  -  ''
# limit - limit  -  limit
# '' - ''  -  ''
# :52428800 - :52428800  -  :52428800
# } - }  -  }
# } - }  -  }
# '' - ''  -  ''
# cachereport - cachereport  -  cachereport
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# origin - origin  -  origin
# '' - ''  -  ''
# '' - ''  -  ''
# mw1326 - mw1326  -  mw1326
# '' - ''  -  ''
# '' - ''  -  ''
# timestamp - timestamp  -  timestamp
# '' - ''  -  ''
# '' - ''  -  ''
# 20200803155324 - 20200803155324  -  20200803155324
# '' - ''  -  ''
# '' - ''  -  ''
# ttl - ttl  -  ttl
# '' - ''  -  ''
# :2592000 - :2592000  -  :2592000
# '' - ''  -  ''
# transientcontent - transientcont  -  transientcontent
# '' - ''  -  ''
# false - fals  -  false
# } - }  -  }
# } - }  -  }
# } - }  -  }
# } - }  -  }
# { - {  -  {
# `` - ``  -  ``
# @ - @  -  @
# context - context  -  context
# '' - ''  -  ''
# '' - ''  -  ''
# https - https  -  http
# \/\/schema.org - \/\/schema.org  -  \/\/schema.org
# '' - ''  -  ''
# '' - ''  -  ''
# @ - @  -  @
# type - type  -  type
# '' - ''  -  ''
# '' - ''  -  ''
# Article - articl  -  Article
# '' - ''  -  ''
# '' - ''  -  ''
# name - name  -  name
# '' - ''  -  ''
# '' - ''  -  ''
# Web - web  -  Web
# mining - mine  -  mining
# '' - ''  -  ''
# '' - ''  -  ''
# url - url  -  url
# '' - ''  -  ''
# '' - ''  -  ''
# https - https  -  http
# \/\/en.wikipedia.org\/wiki\/Web_mining - \/\/en.wikipedia.org\/wiki\/web_min  -  \/\/en.wikipedia.org\/wiki\/Web_mining
# '' - ''  -  ''
# '' - ''  -  ''
# sameAs - samea  -  sameAs
# '' - ''  -  ''
# '' - ''  -  ''
# http - http  -  http
# \/\/www.wikidata.org\/entity\/Q785337 - \/\/www.wikidata.org\/entity\/q785337  -  \/\/www.wikidata.org\/entity\/Q785337
# '' - ''  -  ''
# '' - ''  -  ''
# mainEntity - mainent  -  mainEntity
# '' - ''  -  ''
# '' - ''  -  ''
# http - http  -  http
# \/\/www.wikidata.org\/entity\/Q785337 - \/\/www.wikidata.org\/entity\/q785337  -  \/\/www.wikidata.org\/entity\/Q785337
# '' - ''  -  ''
# '' - ''  -  ''
# author - author  -  author
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# @ - @  -  @
# type - type  -  type
# '' - ''  -  ''
# '' - ''  -  ''
# Organization - organ  -  Organization
# '' - ''  -  ''
# '' - ''  -  ''
# name - name  -  name
# '' - ''  -  ''
# '' - ''  -  ''
# Contributors - contributor  -  Contributors
# Wikimedia - wikimedia  -  Wikimedia
# projects - project  -  project
# '' - ''  -  ''
# } - }  -  }
# '' - ''  -  ''
# publisher - publish  -  publisher
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# @ - @  -  @
# type - type  -  type
# '' - ''  -  ''
# '' - ''  -  ''
# Organization - organ  -  Organization
# '' - ''  -  ''
# '' - ''  -  ''
# name - name  -  name
# '' - ''  -  ''
# '' - ''  -  ''
# Wikimedia - wikimedia  -  Wikimedia
# Foundation - foundat  -  Foundation
# Inc. - inc.  -  Inc.
# '' - ''  -  ''
# '' - ''  -  ''
# logo - logo  -  logo
# '' - ''  -  ''
# { - {  -  {
# `` - ``  -  ``
# @ - @  -  @
# type - type  -  type
# '' - ''  -  ''
# '' - ''  -  ''
# ImageObject - imageobject  -  ImageObject
# '' - ''  -  ''
# '' - ''  -  ''
# url - url  -  url
# '' - ''  -  ''
# '' - ''  -  ''
# https - https  -  http
# \/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png - \/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png  -  \/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png
# '' - ''  -  ''
# } - }  -  }
# } - }  -  }
# '' - ''  -  ''
# datePublished - datepublish  -  datePublished
# '' - ''  -  ''
# '' - ''  -  ''
# 2004-07-08T21:37:06Z - 2004-07-08t21:37:06z  -  2004-07-08T21:37:06Z
# '' - ''  -  ''
# '' - ''  -  ''
# dateModified - datemodifi  -  dateModified
# '' - ''  -  ''
# '' - ''  -  ''
# 2020-07-01T13:43:39Z - 2020-07-01t13:43:39z  -  2020-07-01T13:43:39Z
# '' - ''  -  ''
# } - }  -  }
# RLQ=window.RLQ|| - rlq=window.rlq||  -  RLQ=window.RLQ||
# .push - .push  -  .push
# function - function  -  function
# { - {  -  {
# mw.config.set - mw.config.set  -  mw.config.set
# { - {  -  {
# `` - ``  -  ``
# wgBackendResponseTime - wgbackendresponsetim  -  wgBackendResponseTime
# '' - ''  -  ''
# :94 - :94  -  :94
# '' - ''  -  ''
# wgHostname - wghostnam  -  wgHostname
# '' - ''  -  ''
# '' - ''  -  ''
# mw1409 - mw1409  -  mw1409
# '' - ''  -  ''
# } - }  -  }
# } - }  -  }

# %%
data={"Original Term":filtered_sentence1,"Stemmed Term":stems,"Lemmatized Term":lemma}
import pandas
pandas.DataFrame(data)
# Out:
#                             Original Term  \
# 0                                     Web
# 1                                  mining
# 2                               Wikipedia
# 3     document.documentElement.className=
# 4                                      ''
# ...                                   ...
# 3602                                   ''
# 3603                               mw1409
# 3604                                   ''
# 3605                                    }
# 3606                                    }
#
#                              Stemmed Term                      Lemmatized Term
# 0                                     web                                  Web
# 1                                    mine                               mining
# 2                               wikipedia                            Wikipedia
# 3     document.documentelement.classname=  document.documentElement.className=
# 4                                      ''                                   ''
# ...                                   ...                                  ...
# 3602                                   ''                                   ''
# 3603                               mw1409                               mw1409
# 3604                                   ''                                   ''
# 3605                                    }                                    }
# 3606                                    }                                    }
#
# [3607 rows x 3 columns]

# %%
#5

# %%
frequency1 = {} 
for word in stems: 
    count = frequency1.get(word,0) 
    frequency1[word] = count + 1 
frequency_list1 = frequency1.keys()   
print("stemmed words-",len(frequency_list1))
# Out:
# stemmed words- 1226

# %%
frequency2 = {} 
for word in lemma: 
    count = frequency2.get(word,0) 
    frequency2[word] = count + 1 
frequency_list2 = frequency2.keys()   
print("lemmatized words-",len(frequency_list2))
# Out:
# lemmatized words- 1435

# %%
#6

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
finalwords = []
            
for line in filtered_sentence1:         
        for word in line.split():          
            finalwords.append(word)
tagged = nltk.pos_tag(finalwords)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Sreemanth\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import pandas as pd
df = pd.DataFrame(tagged,columns=['List of Stopwords','POS Tags'])
print(df)
# Out:
#                         List of Stopwords POS Tags
# 0                                     Web      NNP
# 1                                  mining       NN
# 2                               Wikipedia      NNP
# 3     document.documentElement.className=       NN
# 4                                      ''       ''
# ...                                   ...      ...
# 3602                                   ''       ''
# 3603                               mw1409       NN
# 3604                                   ''       ''
# 3605                                    }        )
# 3606                                    }        )
#
# [3607 rows x 2 columns]
