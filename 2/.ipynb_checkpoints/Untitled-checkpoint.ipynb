# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
with open('AI.txt', 'r') as file:
    data = file.read().replace('\n', '')
    
STOP_WORDS = set(stopwords.words('english'))
STOP_WORDS.add('a')
STOP_WORDS.add('they')
STOP_WORDS.add('the')
STOP_WORDS.add('his')
STOP_WORDS.add('.')
STOP_WORDS.add(',')
STOP_WORDS.add('so')
STOP_WORDS.add('and')
STOP_WORDS.add('were')
STOP_WORDS.add('from')
STOP_WORDS.add('that')
STOP_WORDS.add('of')
STOP_WORDS.add('in')
STOP_WORDS.add('only')
STOP_WORDS.add('with')
STOP_WORDS.add('to')

word_tokens = word_tokenize(data)


filtered_sentence1 = [w for w in word_tokens if not w in STOP_WORDS]

print(len(filtered_sentence1))
# Out:
# 511

# %%
with open('ML.txt', 'r') as file:
    data = file.read().replace('\n', '')
    
STOP_WORDS = set(stopwords.words('english'))

STOP_WORDS.add('a')
STOP_WORDS.add('they')
STOP_WORDS.add('the')
STOP_WORDS.add('his')
STOP_WORDS.add('.')
STOP_WORDS.add(',')
STOP_WORDS.add('so')
STOP_WORDS.add('and')
STOP_WORDS.add('were')
STOP_WORDS.add('from')
STOP_WORDS.add('that')
STOP_WORDS.add('of')
STOP_WORDS.add('in')
STOP_WORDS.add('only')
STOP_WORDS.add('with')
STOP_WORDS.add('to')

word_tokens = word_tokenize(data)

##print(word_tokens)
filtered_sentence2 = [w for w in word_tokens if not w in STOP_WORDS]

print(len(filtered_sentence2))
# Out:
# 707

# %%
print("\n\nFrequency of each word in ai.txt : - \n")
d=dict()
for line in filtered_sentence1: 
    line = line.strip() 
    line = line.lower() 
    words1 = line.split(" ") 
    for word in filtered_sentence1: 
        if word in d: 
            d[word] = d[word] + 1
        else: 
            d[word] = 1
  
for key in list(d.keys()): 
    print(key, ":", d[key])
# Out:
# Frequency of each word in ai.txt : -
#
# Since : 511
# invention : 511
# computers : 1022
# machines : 2044
# capability : 511
# perform : 1022
# various : 1022
# tasks : 1022
# went : 511
# growing : 511
# exponentially : 511
# Humans : 511
# developed : 511
# power : 1022
# computer : 5110
# systems : 3066
# terms : 1022
# diverse : 511
# working : 511
# domains : 511
# increasing : 511
# speed : 1022
# reducing : 511
# size : 511
# respect : 511
# time.A : 511
# branch : 511
# Computer : 1022
# Science : 1022
# named : 511
# Artificial : 2044
# Intelligence : 2555
# pursues : 511
# creating : 1022
# intelligent : 4088
# human : 3577
# beings.What : 511
# ? : 2044
# According : 511
# father : 511
# John : 511
# McCarthy : 511
# “ : 1022
# The : 1533
# science : 1022
# engineering : 511
# making : 1022
# especially : 511
# programs : 1022
# ” : 1022
# .Artificial : 511
# way : 1022
# computer-controlled : 511
# robot : 511
# software : 2555
# think : 2044
# intelligently : 511
# ...

# %%
print("\n\nFrequency of each word in ml.txt : - \n")
d=dict()
for line in filtered_sentence2: 
    line = line.strip() 
    line = line.lower() 
    words1 = line.split(" ") 
    for word in filtered_sentence2: 
        if word in d: 
            d[word] = d[word] + 1
        else: 
            d[word] = 1
  
for key in list(d.keys()): 
    print(key, ":", d[key])
# Out:
# Frequency of each word in ml.txt : -
#
# Artificial : 1414
# Intelligence : 2121
# Machine : 707
# Learning : 707
# : : 6363
# Policy : 707
# PaperForewordArtificial : 707
# intelligence : 9191
# technology : 5656
# already : 2121
# impacting : 707
# users : 1414
# interact : 2121
# affected : 707
# Internet : 11312
# In : 707
# near : 707
# future : 1414
# impact : 1414
# likely : 707
# continue : 707
# grow : 1414
# AI : 24038
# potential : 2828
# vastly : 707
# change : 707
# way : 2121
# humans : 707
# digital : 707
# world : 1414
# also : 1414
# work : 707
# socioeconomic : 1414
# institutions : 707
# ï¿½ : 1414
# better : 707
# worse.If : 707
# ensure : 707
# artificial : 6363
# positive : 707
# essential : 707
# stakeholders : 2121
# participate : 707
# debates : 1414
# surrounding : 2121
# AI.In : 707
# paper : 4242
# seek : 707
# provide : 707
# introduction : 707
# policymakers : 707
# wider : 707
# ecosystem.The : 707
# explains : 707
# basics : 707
# behind : 2828
# ...

# %%
if len(f1) != 0 | len(f2) != 0:
    for words in f1:
        for wordds in f2:
            if words == wordds:
                print(words)
# Out:
# perform
# perform
# various
# tasks
# tasks
# developed
# computer
# computer
# systems
# systems
# increasing
# Artificial
# Artificial
# Intelligence
# Intelligence
# Intelligence
# creating
# intelligent
# Artificial
# Artificial
# Intelligence
# Intelligence
# Intelligence
# Artificial
# Artificial
# Intelligence
# Intelligence
# Intelligence
# The
# science
# science
# making
# intelligent
# intelligent
# computer
# computer
# Intelligence
# Intelligence
# Intelligence
# way
# way
# way
# making
# computer
# computer
# think
# intelligent
# humans
# humans
# learn
# learn
# learn
# learn
# work
# trying
# developing
# developing
# intelligent
# computer
# computer
# systems
# systems
# machine
# machine
# machine
# machine
# machine
# think
# like
# humans
# development
# development
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# AI
# creating
# intelligence
# ...
